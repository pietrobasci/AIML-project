# %% [markdown]
# # Weapons Detection - Faster R-CNN
#
# First, we need to install `pycocotools`. This library will be used for computing the evaluation metrics following the COCO metric for intersection over union.

# %%
# %%shell
#
# # Install pycocotools
# git clone https://github.com/cocodataset/cocoapi.git
# cd cocoapi/PythonAPI
# python setup.py build_ext install
# Out:
# fatal: destination path 'cocoapi' already exists and is not an empty directory.
# running build_ext
# skipping 'pycocotools/_mask.c' Cython extension (up-to-date)
# running install
# running bdist_egg
# running egg_info
# writing pycocotools.egg-info/PKG-INFO
# writing dependency_links to pycocotools.egg-info/dependency_links.txt
# writing requirements to pycocotools.egg-info/requires.txt
# writing top-level names to pycocotools.egg-info/top_level.txt
# writing manifest file 'pycocotools.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.6/pycocotools/__init__.py -> build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.6/pycocotools/_mask.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.6/pycocotools/coco.py -> build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.6/pycocotools/cocoeval.py -> build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.6/pycocotools/mask.py -> build/bdist.linux-x86_64/egg/pycocotools
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/coco.py to coco.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/cocoeval.py to cocoeval.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/mask.py to mask.cpython-36.pyc
# creating stub loader for pycocotools/_mask.cpython-36m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/_mask.py to _mask.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# pycocotools.__pycache__._mask.cpython-36: module references __file__
# creating 'dist/pycocotools-2.0-py3.6-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pycocotools-2.0-py3.6-linux-x86_64.egg
# removing '/usr/local/lib/python3.6/dist-packages/pycocotools-2.0-py3.6-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.6/dist-packages/pycocotools-2.0-py3.6-linux-x86_64.egg
# Extracting pycocotools-2.0-py3.6-linux-x86_64.egg to /usr/local/lib/python3.6/dist-packages
# pycocotools 2.0 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.6/dist-packages/pycocotools-2.0-py3.6-linux-x86_64.egg
# Processing dependencies for pycocotools==2.0
# Searching for matplotlib==3.1.3
# Best match: matplotlib 3.1.3
# Adding matplotlib 3.1.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Cython==0.29.14
# Best match: Cython 0.29.14
# Adding Cython 0.29.14 to easy-install.pth file
# Installing cygdb script to /usr/local/bin
# Installing cython script to /usr/local/bin
# Installing cythonize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for setuptools==45.1.0
# Best match: setuptools 45.1.0
# Adding setuptools 45.1.0 to easy-install.pth file
# Installing easy_install script to /usr/local/bin
# Installing easy_install-3.8 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for python-dateutil==2.6.1
# Best match: python-dateutil 2.6.1
# Adding python-dateutil 2.6.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.17.5
# Best match: numpy 1.17.5
# Adding numpy 1.17.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for kiwisolver==1.1.0
# Best match: kiwisolver 1.1.0
# Adding kiwisolver 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyparsing==2.4.6
# Best match: pyparsing 2.4.6
# Adding pyparsing 2.4.6 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for cycler==0.10.0
# Best match: cycler 0.10.0
# Adding cycler 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.12.0
# Best match: six 1.12.0
# Adding six 1.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for pycocotools==2.0

# %% [markdown]
# ### Dataset
#
# Download and extract data, present in a zip file at (github link)

# %%
# %%shell
#
# # download the dataset
# # wget https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip .
# git clone https://github.com/SadCl0wn/mirto.git
#
# # extract it in the current folder
# #unzip mirto/ML-Project.zip
# unzip ML-Project.zip
# Out:
# fatal: destination path 'mirto' already exists and is not an empty directory.
# Archive:  ML-Project.zip
# replace ML-Project/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# The data is structured as follows
# ```
# ML-Project/
#   images/
#     armas (1).jpg
#     armas (2).jpg
#     armas (3).jpg
#     armas (4).jpg
#     ...
#   annotations/
#     armas (1).xml
#     armas (2).xml
#     armas (3).xml
#     armas (4).xml
#     ...
# ```
#
# Here is one example of an image in the dataset.

# %%
from PIL import Image
Image.open('ML-Project/images/armas (12).jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=315x450 at 0x7FD4F5CA7400>

# %% [markdown]
# Defining a `torch.utils.data.Dataset` class for this dataset.

# %%
# !pip3 install 'xmltodict'

import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import xmltodict

class WeaponDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms=None):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs = list(sorted(i for i in os.listdir(os.path.join(root, "images"))
                                 if i.lower().endswith(('.png', '.jpg', '.jpeg'))))
        self.annotations = list(sorted(a for a in os.listdir(os.path.join(root, "annotations"))
                                        if a.lower().endswith(('.xml'))))

    def __getitem__(self, idx):
        # load images ad annotations
        img_path = os.path.join(self.root, "images", self.imgs[idx])
        annotations_path = os.path.join(self.root, "annotations", self.annotations[idx])
        img = Image.open(img_path).convert("RGB")
        
        boxes = []
        
        x = xmltodict.parse(open(annotations_path, 'rb'))        
        objects = []

        if isinstance(x['annotation']['object'], list):
          objects = x['annotation']['object']
        else:
          objects.append(x['annotation']['object'])
        
        for obj in objects:
            bndbox = obj['bndbox']
            bndbox = np.array([int(bndbox['xmin']), int(bndbox['ymin']), 
                               int(bndbox['xmax']), int(bndbox['ymax'])])
            box = [None] * 4
            box[0] = bndbox[0]
            box[1] = bndbox[1]
            box[2] = bndbox[2]
            box[3] = bndbox[3]             
            boxes.append(box)
        
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # there is only one class
        labels = torch.ones(len(objects), dtype=torch.int64)
        #labels = torch.ones((len(self.imgs)), dtype=torch.int64)
        #masks = torch.as_tensor(masks, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = []
        if len(boxes) != 0:
          area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros(len(objects), dtype=torch.int64)
        #iscrowd = torch.zeros((len(self.imgs)), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        #target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)
# Out:
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.6/dist-packages (0.12.0)

# %% [markdown]
# ## Defining the model
#
# In this work we will use Faster R-CNN.

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

      
def get_instance_segmentation_model(num_classes):
    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

    # replace the classifier with a new one, that has
    # num_classes which is user-defined
    num_classes = 2  # 1 class (weapon) + background
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
                                                
    return model

# %% [markdown]
# ## Training and evaluation functions
#
# In `references/detection/,` we have a number of helper functions to simplify training and evaluating detection models.
# Here, we will use `references/detection/engine.py`, `references/detection/utils.py` and `references/detection/transforms.py`.
#
# Let's copy those files (and their dependencies) in here so that they are available in the notebook

# %%
# %%shell
#
# # Download TorchVision repo to use some files from
# # references/detection
# #git clone https://github.com/pytorch/vision.git
# #git checkout v0.3.0
#
# cd mirto
#
# cp Faster_R_CNN/utils.py ../
# cp Faster_R_CNN/transforms.py ../
# cp Faster_R_CNN/coco_eval.py ../
# cp Faster_R_CNN/engine.py ../
# cp Faster_R_CNN/coco_utils.py ../

# %% [markdown]
# Let's write some helper functions for data augmentation / transformation, which leverages the functions in `refereces/detection` that we have just copied:

# %%
from engine import train_one_epoch, evaluate
import utils
import copy
import transforms as T


def get_transform(train):
    transforms = []
    # converts the image, a PIL image, into a PyTorch Tensor
    transforms.append(T.ToTensor())
    if train:
        # during training, randomly flip the training images
        # and ground-truth for data augmentation
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# %% [markdown]
# Note that we do not need to add a mean/std normalization nor image rescaling in the data transforms, as those are handled internally by the Mask R-CNN model.

# %% [markdown]
# ### Prepare dataloader
#
# We now have the dataset class, the models and the data transforms. Let's instantiate them

# %%
# use our dataset and defined transformations
dataset = WeaponDataset('ML-Project', get_transform(train=True))
dataset_val = WeaponDataset('ML-Project', get_transform(train=False))
dataset_test = WeaponDataset('ML-Project', get_transform(train=False))

# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:-1000])
dataset_val = torch.utils.data.Subset(dataset_val, indices[2000:2500])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-500:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=2, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_val = torch.utils.data.DataLoader(
    dataset_val, batch_size=1, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# Check dataset sizes
print('Train Dataset: {}'.format(len(dataset)))
print('Validation Dataset: {}'.format(len(dataset_val)))
print('Test Dataset: {}'.format(len(dataset_test)))
# Out:
# Train Dataset: 2000
# Validation Dataset: 500
# Test Dataset: 500

# %% [markdown]
# Now let's instantiate the model and the optimizer

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has two classes only - background and person
num_classes = 2

# get the model using our helper function
model = get_instance_segmentation_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %% [markdown]
# And now let's train the model for 10 epochs, evaluating at the end of every epoch.

# %%
# let's train it for 10 epochs
num_epochs = 15

losses = []
losses_classifier = []
losses_box_reg = []
losses_objectness = []
losses_rpn_box_reg = []
train_acc = []
val_acc = []

best_net = None
best_accuracy = 0.0

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    losses_log = train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)    
    
    # update the learning rate
    lr_scheduler.step()
        
    # evaluate on the train dataset
    _, confmat = evaluate(model, 
                          data_loader, 
                          conf_threshold=0.9, 
                          iou_threshold=0.5, device=device)
    train_acc.append(confmat.compute()[0].item())
       
    # evaluate on the validation dataset
    _, confmat = evaluate(model, 
                          data_loader_val, 
                          conf_threshold=0.9, 
                          iou_threshold=0.5, device=device)
    
    accuracy = confmat.compute()[0].item()
    val_acc.append(accuracy)
    print(accuracy)
    print(best_accuracy)
    
    # Update the best model
    if accuracy > best_accuracy:
      best_accuracy = accuracy
      best_net = copy.deepcopy(model)

    # trace losses
    losses.extend(losses_log[0])
    losses_classifier.extend(losses_log[1])
    losses_box_reg.extend(losses_log[2])
    losses_objectness.extend(losses_log[3])
    losses_rpn_box_reg.extend(losses_log[4])


utils.plot_loss_accuracy_trend([losses, 
                                losses_classifier, 
                                losses_box_reg, 
                                losses_objectness, 
                                losses_rpn_box_reg], [train_acc, val_acc])


# final test on test set
_, _ = evaluate(best_net, data_loader_test, conf_threshold=0.9, iou_threshold=0.5, device=device)
# Out:
# Epoch: [0]  [   0/1000]  eta: 0:20:53  lr: 0.000010  loss: 0.8352 (0.8352)  loss_classifier: 0.7406 (0.7406)  loss_box_reg: 0.0818 (0.0818)  loss_objectness: 0.0023 (0.0023)  loss_rpn_box_reg: 0.0105 (0.0105)  time: 1.2539  data: 0.3541  max mem: 2335
# Epoch: [0]  [  10/1000]  eta: 0:10:18  lr: 0.000060  loss: 0.8074 (0.7995)  loss_classifier: 0.6380 (0.6515)  loss_box_reg: 0.0818 (0.1108)  loss_objectness: 0.0046 (0.0170)  loss_rpn_box_reg: 0.0124 (0.0202)  time: 0.6251  data: 0.0365  max mem: 3378
# Epoch: [0]  [  20/1000]  eta: 0:10:24  lr: 0.000110  loss: 0.5671 (0.6208)  loss_classifier: 0.4458 (0.4828)  loss_box_reg: 0.0812 (0.0995)  loss_objectness: 0.0064 (0.0141)  loss_rpn_box_reg: 0.0173 (0.0243)  time: 0.6059  data: 0.0053  max mem: 4128
# Epoch: [0]  [  30/1000]  eta: 0:10:04  lr: 0.000160  loss: 0.2772 (0.5015)  loss_classifier: 0.1638 (0.3671)  loss_box_reg: 0.0743 (0.0900)  loss_objectness: 0.0147 (0.0198)  loss_rpn_box_reg: 0.0174 (0.0246)  time: 0.6228  data: 0.0073  max mem: 4128
# Epoch: [0]  [  40/1000]  eta: 0:09:55  lr: 0.000210  loss: 0.2474 (0.4405)  loss_classifier: 0.1180 (0.3082)  loss_box_reg: 0.0678 (0.0877)  loss_objectness: 0.0131 (0.0211)  loss_rpn_box_reg: 0.0115 (0.0236)  time: 0.6037  data: 0.0071  max mem: 4128
# Epoch: [0]  [  50/1000]  eta: 0:09:55  lr: 0.000260  loss: 0.2078 (0.3941)  loss_classifier: 0.0943 (0.2661)  loss_box_reg: 0.0610 (0.0819)  loss_objectness: 0.0046 (0.0198)  loss_rpn_box_reg: 0.0194 (0.0263)  time: 0.6331  data: 0.0052  max mem: 4128
# Epoch: [0]  [  60/1000]  eta: 0:09:51  lr: 0.000310  loss: 0.2067 (0.3637)  loss_classifier: 0.0927 (0.2388)  loss_box_reg: 0.0645 (0.0804)  loss_objectness: 0.0038 (0.0184)  loss_rpn_box_reg: 0.0291 (0.0261)  time: 0.6466  data: 0.0051  max mem: 4128
# Epoch: [0]  [  70/1000]  eta: 0:09:45  lr: 0.000360  loss: 0.1958 (0.3403)  loss_classifier: 0.0918 (0.2177)  loss_box_reg: 0.0701 (0.0789)  loss_objectness: 0.0054 (0.0172)  loss_rpn_box_reg: 0.0207 (0.0265)  time: 0.6362  data: 0.0053  max mem: 4236
# Epoch: [0]  [  80/1000]  eta: 0:09:34  lr: 0.000410  loss: 0.1958 (0.3226)  loss_classifier: 0.0804 (0.2004)  loss_box_reg: 0.0675 (0.0777)  loss_objectness: 0.0072 (0.0167)  loss_rpn_box_reg: 0.0356 (0.0278)  time: 0.6090  data: 0.0053  max mem: 4236
# Epoch: [0]  [  90/1000]  eta: 0:09:29  lr: 0.000460  loss: 0.2045 (0.3114)  loss_classifier: 0.0823 (0.1892)  loss_box_reg: 0.0752 (0.0786)  loss_objectness: 0.0091 (0.0164)  loss_rpn_box_reg: 0.0336 (0.0272)  time: 0.6093  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 100/1000]  eta: 0:09:19  lr: 0.000510  loss: 0.1884 (0.3001)  loss_classifier: 0.0927 (0.1786)  loss_box_reg: 0.0762 (0.0797)  loss_objectness: 0.0052 (0.0153)  loss_rpn_box_reg: 0.0140 (0.0265)  time: 0.6099  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 110/1000]  eta: 0:09:11  lr: 0.000560  loss: 0.1884 (0.2943)  loss_classifier: 0.0750 (0.1714)  loss_box_reg: 0.0809 (0.0822)  loss_objectness: 0.0043 (0.0148)  loss_rpn_box_reg: 0.0140 (0.0260)  time: 0.5940  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 120/1000]  eta: 0:09:05  lr: 0.000610  loss: 0.1738 (0.2832)  loss_classifier: 0.0726 (0.1620)  loss_box_reg: 0.0740 (0.0809)  loss_objectness: 0.0052 (0.0143)  loss_rpn_box_reg: 0.0183 (0.0261)  time: 0.6138  data: 0.0049  max mem: 4236
# Epoch: [0]  [ 130/1000]  eta: 0:09:00  lr: 0.000660  loss: 0.1593 (0.2743)  loss_classifier: 0.0506 (0.1541)  loss_box_reg: 0.0647 (0.0805)  loss_objectness: 0.0024 (0.0135)  loss_rpn_box_reg: 0.0286 (0.0262)  time: 0.6306  data: 0.0049  max mem: 4236
# Epoch: [0]  [ 140/1000]  eta: 0:08:53  lr: 0.000710  loss: 0.1457 (0.2662)  loss_classifier: 0.0543 (0.1477)  loss_box_reg: 0.0629 (0.0798)  loss_objectness: 0.0017 (0.0128)  loss_rpn_box_reg: 0.0267 (0.0260)  time: 0.6213  data: 0.0053  max mem: 4236
# Epoch: [0]  [ 150/1000]  eta: 0:08:49  lr: 0.000760  loss: 0.1486 (0.2637)  loss_classifier: 0.0605 (0.1426)  loss_box_reg: 0.0699 (0.0804)  loss_objectness: 0.0044 (0.0144)  loss_rpn_box_reg: 0.0252 (0.0263)  time: 0.6306  data: 0.0057  max mem: 4236
# Epoch: [0]  [ 160/1000]  eta: 0:08:42  lr: 0.000810  loss: 0.1561 (0.2585)  loss_classifier: 0.0602 (0.1381)  loss_box_reg: 0.0713 (0.0800)  loss_objectness: 0.0075 (0.0145)  loss_rpn_box_reg: 0.0244 (0.0260)  time: 0.6308  data: 0.0060  max mem: 4236
# Epoch: [0]  [ 170/1000]  eta: 0:08:37  lr: 0.000860  loss: 0.1561 (0.2547)  loss_classifier: 0.0597 (0.1341)  loss_box_reg: 0.0686 (0.0798)  loss_objectness: 0.0084 (0.0145)  loss_rpn_box_reg: 0.0251 (0.0263)  time: 0.6352  data: 0.0057  max mem: 4236
# Epoch: [0]  [ 180/1000]  eta: 0:08:31  lr: 0.000910  loss: 0.1290 (0.2492)  loss_classifier: 0.0415 (0.1295)  loss_box_reg: 0.0489 (0.0786)  loss_objectness: 0.0094 (0.0146)  loss_rpn_box_reg: 0.0288 (0.0265)  time: 0.6361  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 190/1000]  eta: 0:08:23  lr: 0.000960  loss: 0.1201 (0.2440)  loss_classifier: 0.0415 (0.1257)  loss_box_reg: 0.0418 (0.0772)  loss_objectness: 0.0063 (0.0149)  loss_rpn_box_reg: 0.0274 (0.0263)  time: 0.5981  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 200/1000]  eta: 0:08:18  lr: 0.001010  loss: 0.1575 (0.2431)  loss_classifier: 0.0536 (0.1243)  loss_box_reg: 0.0559 (0.0776)  loss_objectness: 0.0063 (0.0149)  loss_rpn_box_reg: 0.0192 (0.0262)  time: 0.6194  data: 0.0054  max mem: 4236
# Epoch: [0]  [ 210/1000]  eta: 0:08:11  lr: 0.001060  loss: 0.1493 (0.2382)  loss_classifier: 0.0583 (0.1213)  loss_box_reg: 0.0551 (0.0764)  loss_objectness: 0.0079 (0.0147)  loss_rpn_box_reg: 0.0111 (0.0259)  time: 0.6341  data: 0.0054  max mem: 4236
# Epoch: [0]  [ 220/1000]  eta: 0:08:04  lr: 0.001110  loss: 0.1225 (0.2329)  loss_classifier: 0.0508 (0.1179)  loss_box_reg: 0.0441 (0.0748)  loss_objectness: 0.0092 (0.0145)  loss_rpn_box_reg: 0.0229 (0.0257)  time: 0.6006  data: 0.0050  max mem: 4236
# Epoch: [0]  [ 230/1000]  eta: 0:07:57  lr: 0.001160  loss: 0.1176 (0.2295)  loss_classifier: 0.0430 (0.1159)  loss_box_reg: 0.0420 (0.0736)  loss_objectness: 0.0082 (0.0144)  loss_rpn_box_reg: 0.0259 (0.0256)  time: 0.5937  data: 0.0049  max mem: 4236
# Epoch: [0]  [ 240/1000]  eta: 0:07:50  lr: 0.001210  loss: 0.1090 (0.2245)  loss_classifier: 0.0399 (0.1127)  loss_box_reg: 0.0313 (0.0721)  loss_objectness: 0.0016 (0.0138)  loss_rpn_box_reg: 0.0235 (0.0258)  time: 0.6039  data: 0.0055  max mem: 4236
# Epoch: [0]  [ 250/1000]  eta: 0:07:44  lr: 0.001260  loss: 0.1009 (0.2199)  loss_classifier: 0.0347 (0.1097)  loss_box_reg: 0.0313 (0.0706)  loss_objectness: 0.0016 (0.0135)  loss_rpn_box_reg: 0.0233 (0.0261)  time: 0.6058  data: 0.0057  max mem: 4236
# Epoch: [0]  [ 260/1000]  eta: 0:07:36  lr: 0.001310  loss: 0.0970 (0.2155)  loss_classifier: 0.0331 (0.1071)  loss_box_reg: 0.0329 (0.0694)  loss_objectness: 0.0021 (0.0132)  loss_rpn_box_reg: 0.0180 (0.0259)  time: 0.5876  data: 0.0068  max mem: 4236
# Epoch: [0]  [ 270/1000]  eta: 0:07:30  lr: 0.001360  loss: 0.0970 (0.2129)  loss_classifier: 0.0432 (0.1055)  loss_box_reg: 0.0315 (0.0685)  loss_objectness: 0.0022 (0.0134)  loss_rpn_box_reg: 0.0176 (0.0256)  time: 0.5898  data: 0.0066  max mem: 4236
# Epoch: [0]  [ 280/1000]  eta: 0:07:24  lr: 0.001410  loss: 0.1129 (0.2118)  loss_classifier: 0.0449 (0.1049)  loss_box_reg: 0.0345 (0.0681)  loss_objectness: 0.0032 (0.0133)  loss_rpn_box_reg: 0.0121 (0.0254)  time: 0.6154  data: 0.0056  max mem: 4236
# Epoch: [0]  [ 290/1000]  eta: 0:07:17  lr: 0.001460  loss: 0.1274 (0.2094)  loss_classifier: 0.0527 (0.1034)  loss_box_reg: 0.0345 (0.0671)  loss_objectness: 0.0050 (0.0132)  loss_rpn_box_reg: 0.0271 (0.0257)  time: 0.6170  data: 0.0056  max mem: 4236
# Epoch: [0]  [ 300/1000]  eta: 0:07:13  lr: 0.001510  loss: 0.1222 (0.2061)  loss_classifier: 0.0460 (0.1012)  loss_box_reg: 0.0340 (0.0660)  loss_objectness: 0.0046 (0.0130)  loss_rpn_box_reg: 0.0293 (0.0258)  time: 0.6460  data: 0.0054  max mem: 4236
# Epoch: [0]  [ 310/1000]  eta: 0:07:06  lr: 0.001560  loss: 0.0945 (0.2024)  loss_classifier: 0.0300 (0.0989)  loss_box_reg: 0.0277 (0.0647)  loss_objectness: 0.0014 (0.0127)  loss_rpn_box_reg: 0.0272 (0.0261)  time: 0.6298  data: 0.0053  max mem: 4236
# Epoch: [0]  [ 320/1000]  eta: 0:06:59  lr: 0.001610  loss: 0.0945 (0.1996)  loss_classifier: 0.0250 (0.0971)  loss_box_reg: 0.0223 (0.0639)  loss_objectness: 0.0018 (0.0125)  loss_rpn_box_reg: 0.0272 (0.0262)  time: 0.5787  data: 0.0056  max mem: 4236
# Epoch: [0]  [ 330/1000]  eta: 0:06:53  lr: 0.001660  loss: 0.1144 (0.1977)  loss_classifier: 0.0449 (0.0960)  loss_box_reg: 0.0399 (0.0635)  loss_objectness: 0.0022 (0.0122)  loss_rpn_box_reg: 0.0207 (0.0260)  time: 0.6224  data: 0.0068  max mem: 4236
# Epoch: [0]  [ 340/1000]  eta: 0:06:47  lr: 0.001710  loss: 0.1144 (0.1949)  loss_classifier: 0.0550 (0.0945)  loss_box_reg: 0.0422 (0.0627)  loss_objectness: 0.0029 (0.0121)  loss_rpn_box_reg: 0.0122 (0.0256)  time: 0.6404  data: 0.0066  max mem: 4236
# Epoch: [0]  [ 350/1000]  eta: 0:06:42  lr: 0.001760  loss: 0.0923 (0.1920)  loss_classifier: 0.0349 (0.0928)  loss_box_reg: 0.0349 (0.0620)  loss_objectness: 0.0027 (0.0119)  loss_rpn_box_reg: 0.0095 (0.0253)  time: 0.6333  data: 0.0058  max mem: 4236
# Epoch: [0]  [ 360/1000]  eta: 0:06:36  lr: 0.001810  loss: 0.0963 (0.1900)  loss_classifier: 0.0349 (0.0914)  loss_box_reg: 0.0314 (0.0614)  loss_objectness: 0.0029 (0.0117)  loss_rpn_box_reg: 0.0150 (0.0255)  time: 0.6409  data: 0.0058  max mem: 4236
# Epoch: [0]  [ 370/1000]  eta: 0:06:29  lr: 0.001860  loss: 0.0993 (0.1875)  loss_classifier: 0.0295 (0.0901)  loss_box_reg: 0.0280 (0.0606)  loss_objectness: 0.0017 (0.0115)  loss_rpn_box_reg: 0.0171 (0.0253)  time: 0.6118  data: 0.0067  max mem: 4236
# Epoch: [0]  [ 380/1000]  eta: 0:06:23  lr: 0.001910  loss: 0.0880 (0.1850)  loss_classifier: 0.0295 (0.0887)  loss_box_reg: 0.0221 (0.0598)  loss_objectness: 0.0015 (0.0113)  loss_rpn_box_reg: 0.0176 (0.0252)  time: 0.5969  data: 0.0067  max mem: 4236
# Epoch: [0]  [ 390/1000]  eta: 0:06:16  lr: 0.001960  loss: 0.0900 (0.1831)  loss_classifier: 0.0306 (0.0876)  loss_box_reg: 0.0280 (0.0593)  loss_objectness: 0.0021 (0.0111)  loss_rpn_box_reg: 0.0240 (0.0252)  time: 0.6080  data: 0.0054  max mem: 4236
# Epoch: [0]  [ 400/1000]  eta: 0:06:10  lr: 0.002010  loss: 0.1117 (0.1814)  loss_classifier: 0.0389 (0.0865)  loss_box_reg: 0.0280 (0.0585)  loss_objectness: 0.0025 (0.0111)  loss_rpn_box_reg: 0.0258 (0.0252)  time: 0.6119  data: 0.0049  max mem: 4236
# Epoch: [0]  [ 410/1000]  eta: 0:06:04  lr: 0.002060  loss: 0.1105 (0.1802)  loss_classifier: 0.0403 (0.0857)  loss_box_reg: 0.0299 (0.0582)  loss_objectness: 0.0062 (0.0111)  loss_rpn_box_reg: 0.0225 (0.0252)  time: 0.6267  data: 0.0052  max mem: 4236
# Epoch: [0]  [ 420/1000]  eta: 0:05:58  lr: 0.002110  loss: 0.1105 (0.1788)  loss_classifier: 0.0407 (0.0850)  loss_box_reg: 0.0402 (0.0579)  loss_objectness: 0.0062 (0.0111)  loss_rpn_box_reg: 0.0206 (0.0249)  time: 0.6356  data: 0.0053  max mem: 4236
# Epoch: [0]  [ 430/1000]  eta: 0:05:52  lr: 0.002160  loss: 0.1170 (0.1774)  loss_classifier: 0.0429 (0.0842)  loss_box_reg: 0.0402 (0.0573)  loss_objectness: 0.0049 (0.0109)  loss_rpn_box_reg: 0.0133 (0.0250)  time: 0.6099  data: 0.0060  max mem: 4236
# Epoch: [0]  [ 440/1000]  eta: 0:05:45  lr: 0.002210  loss: 0.1099 (0.1757)  loss_classifier: 0.0349 (0.0831)  loss_box_reg: 0.0207 (0.0565)  loss_objectness: 0.0042 (0.0109)  loss_rpn_box_reg: 0.0259 (0.0252)  time: 0.6021  data: 0.0060  max mem: 4236
# Epoch: [0]  [ 450/1000]  eta: 0:05:39  lr: 0.002260  loss: 0.0790 (0.1738)  loss_classifier: 0.0315 (0.0821)  loss_box_reg: 0.0205 (0.0558)  loss_objectness: 0.0026 (0.0108)  loss_rpn_box_reg: 0.0246 (0.0251)  time: 0.6014  data: 0.0052  max mem: 4236
# Epoch: [0]  [ 460/1000]  eta: 0:05:33  lr: 0.002310  loss: 0.0994 (0.1726)  loss_classifier: 0.0452 (0.0815)  loss_box_reg: 0.0336 (0.0555)  loss_objectness: 0.0026 (0.0107)  loss_rpn_box_reg: 0.0098 (0.0249)  time: 0.6228  data: 0.0056  max mem: 4236
# Epoch: [0]  [ 470/1000]  eta: 0:05:27  lr: 0.002360  loss: 0.1006 (0.1713)  loss_classifier: 0.0489 (0.0807)  loss_box_reg: 0.0325 (0.0551)  loss_objectness: 0.0027 (0.0106)  loss_rpn_box_reg: 0.0110 (0.0248)  time: 0.6192  data: 0.0058  max mem: 4236
# Epoch: [0]  [ 480/1000]  eta: 0:05:21  lr: 0.002410  loss: 0.0941 (0.1703)  loss_classifier: 0.0410 (0.0804)  loss_box_reg: 0.0268 (0.0548)  loss_objectness: 0.0020 (0.0105)  loss_rpn_box_reg: 0.0251 (0.0247)  time: 0.6272  data: 0.0055  max mem: 4236
# Epoch: [0]  [ 490/1000]  eta: 0:05:15  lr: 0.002460  loss: 0.0952 (0.1691)  loss_classifier: 0.0430 (0.0795)  loss_box_reg: 0.0239 (0.0543)  loss_objectness: 0.0020 (0.0105)  loss_rpn_box_reg: 0.0133 (0.0248)  time: 0.6582  data: 0.0053  max mem: 4236
# Epoch: [0]  [ 500/1000]  eta: 0:05:09  lr: 0.002510  loss: 0.0952 (0.1677)  loss_classifier: 0.0428 (0.0789)  loss_box_reg: 0.0210 (0.0539)  loss_objectness: 0.0016 (0.0104)  loss_rpn_box_reg: 0.0105 (0.0246)  time: 0.6350  data: 0.0049  max mem: 4236
# Epoch: [0]  [ 510/1000]  eta: 0:05:03  lr: 0.002560  loss: 0.0779 (0.1670)  loss_classifier: 0.0359 (0.0785)  loss_box_reg: 0.0222 (0.0536)  loss_objectness: 0.0033 (0.0104)  loss_rpn_box_reg: 0.0129 (0.0245)  time: 0.6321  data: 0.0048  max mem: 4236
# Epoch: [0]  [ 520/1000]  eta: 0:04:56  lr: 0.002610  loss: 0.0822 (0.1655)  loss_classifier: 0.0350 (0.0777)  loss_box_reg: 0.0225 (0.0531)  loss_objectness: 0.0037 (0.0102)  loss_rpn_box_reg: 0.0141 (0.0244)  time: 0.6119  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 530/1000]  eta: 0:04:50  lr: 0.002660  loss: 0.0960 (0.1649)  loss_classifier: 0.0445 (0.0774)  loss_box_reg: 0.0237 (0.0530)  loss_objectness: 0.0029 (0.0101)  loss_rpn_box_reg: 0.0141 (0.0243)  time: 0.5984  data: 0.0054  max mem: 4236
# Epoch: [0]  [ 540/1000]  eta: 0:04:44  lr: 0.002710  loss: 0.0954 (0.1635)  loss_classifier: 0.0332 (0.0766)  loss_box_reg: 0.0220 (0.0525)  loss_objectness: 0.0022 (0.0100)  loss_rpn_box_reg: 0.0194 (0.0244)  time: 0.6276  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 550/1000]  eta: 0:04:38  lr: 0.002760  loss: 0.0905 (0.1626)  loss_classifier: 0.0271 (0.0760)  loss_box_reg: 0.0185 (0.0521)  loss_objectness: 0.0043 (0.0101)  loss_rpn_box_reg: 0.0247 (0.0244)  time: 0.6073  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 560/1000]  eta: 0:04:32  lr: 0.002810  loss: 0.1028 (0.1615)  loss_classifier: 0.0356 (0.0754)  loss_box_reg: 0.0246 (0.0517)  loss_objectness: 0.0051 (0.0100)  loss_rpn_box_reg: 0.0247 (0.0244)  time: 0.6095  data: 0.0054  max mem: 4236
# Epoch: [0]  [ 570/1000]  eta: 0:04:25  lr: 0.002860  loss: 0.0986 (0.1610)  loss_classifier: 0.0356 (0.0752)  loss_box_reg: 0.0224 (0.0514)  loss_objectness: 0.0038 (0.0099)  loss_rpn_box_reg: 0.0205 (0.0245)  time: 0.6135  data: 0.0052  max mem: 4236
# Epoch: [0]  [ 580/1000]  eta: 0:04:19  lr: 0.002910  loss: 0.0786 (0.1597)  loss_classifier: 0.0278 (0.0744)  loss_box_reg: 0.0219 (0.0509)  loss_objectness: 0.0018 (0.0098)  loss_rpn_box_reg: 0.0281 (0.0246)  time: 0.5714  data: 0.0051  max mem: 4236
# Epoch: [0]  [ 590/1000]  eta: 0:04:13  lr: 0.002960  loss: 0.0886 (0.1603)  loss_classifier: 0.0384 (0.0746)  loss_box_reg: 0.0279 (0.0511)  loss_objectness: 0.0022 (0.0100)  loss_rpn_box_reg: 0.0281 (0.0247)  time: 0.6022  data: 0.0052  max mem: 4236
# Epoch: [0]  [ 600/1000]  eta: 0:04:07  lr: 0.003010  loss: 0.1084 (0.1594)  loss_classifier: 0.0484 (0.0741)  loss_box_reg: 0.0298 (0.0507)  loss_objectness: 0.0063 (0.0100)  loss_rpn_box_reg: 0.0185 (0.0246)  time: 0.6365  data: 0.0054  max mem: 4236
# Epoch: [0]  [ 610/1000]  eta: 0:04:01  lr: 0.003060  loss: 0.1152 (0.1591)  loss_classifier: 0.0512 (0.0740)  loss_box_reg: 0.0313 (0.0506)  loss_objectness: 0.0043 (0.0101)  loss_rpn_box_reg: 0.0126 (0.0245)  time: 0.6564  data: 0.0057  max mem: 4316
# Epoch: [0]  [ 620/1000]  eta: 0:03:55  lr: 0.003110  loss: 0.1157 (0.1585)  loss_classifier: 0.0579 (0.0737)  loss_box_reg: 0.0235 (0.0503)  loss_objectness: 0.0044 (0.0100)  loss_rpn_box_reg: 0.0140 (0.0244)  time: 0.6470  data: 0.0061  max mem: 4316
# Epoch: [0]  [ 630/1000]  eta: 0:03:49  lr: 0.003160  loss: 0.0987 (0.1579)  loss_classifier: 0.0420 (0.0733)  loss_box_reg: 0.0250 (0.0502)  loss_objectness: 0.0059 (0.0100)  loss_rpn_box_reg: 0.0207 (0.0244)  time: 0.6531  data: 0.0061  max mem: 4316
# Epoch: [0]  [ 640/1000]  eta: 0:03:43  lr: 0.003210  loss: 0.1007 (0.1579)  loss_classifier: 0.0420 (0.0736)  loss_box_reg: 0.0321 (0.0500)  loss_objectness: 0.0068 (0.0100)  loss_rpn_box_reg: 0.0147 (0.0243)  time: 0.6658  data: 0.0062  max mem: 4316
# Epoch: [0]  [ 650/1000]  eta: 0:03:36  lr: 0.003260  loss: 0.0936 (0.1570)  loss_classifier: 0.0429 (0.0732)  loss_box_reg: 0.0274 (0.0496)  loss_objectness: 0.0049 (0.0099)  loss_rpn_box_reg: 0.0103 (0.0242)  time: 0.6219  data: 0.0061  max mem: 4316
# Epoch: [0]  [ 660/1000]  eta: 0:03:30  lr: 0.003310  loss: 0.0882 (0.1565)  loss_classifier: 0.0434 (0.0728)  loss_box_reg: 0.0228 (0.0494)  loss_objectness: 0.0049 (0.0100)  loss_rpn_box_reg: 0.0195 (0.0242)  time: 0.6198  data: 0.0052  max mem: 4316
# Epoch: [0]  [ 670/1000]  eta: 0:03:24  lr: 0.003360  loss: 0.1019 (0.1558)  loss_classifier: 0.0461 (0.0725)  loss_box_reg: 0.0310 (0.0492)  loss_objectness: 0.0045 (0.0100)  loss_rpn_box_reg: 0.0154 (0.0241)  time: 0.6216  data: 0.0054  max mem: 4316
# Epoch: [0]  [ 680/1000]  eta: 0:03:18  lr: 0.003410  loss: 0.0967 (0.1552)  loss_classifier: 0.0427 (0.0722)  loss_box_reg: 0.0259 (0.0490)  loss_objectness: 0.0053 (0.0099)  loss_rpn_box_reg: 0.0148 (0.0241)  time: 0.6318  data: 0.0058  max mem: 4316
# Epoch: [0]  [ 690/1000]  eta: 0:03:12  lr: 0.003460  loss: 0.0899 (0.1544)  loss_classifier: 0.0318 (0.0717)  loss_box_reg: 0.0259 (0.0488)  loss_objectness: 0.0024 (0.0098)  loss_rpn_box_reg: 0.0250 (0.0241)  time: 0.6152  data: 0.0056  max mem: 4316
# Epoch: [0]  [ 700/1000]  eta: 0:03:06  lr: 0.003510  loss: 0.0831 (0.1535)  loss_classifier: 0.0303 (0.0712)  loss_box_reg: 0.0299 (0.0485)  loss_objectness: 0.0019 (0.0097)  loss_rpn_box_reg: 0.0169 (0.0240)  time: 0.6132  data: 0.0052  max mem: 4316
# Epoch: [0]  [ 710/1000]  eta: 0:02:59  lr: 0.003560  loss: 0.0709 (0.1525)  loss_classifier: 0.0253 (0.0707)  loss_box_reg: 0.0170 (0.0481)  loss_objectness: 0.0021 (0.0096)  loss_rpn_box_reg: 0.0169 (0.0240)  time: 0.6292  data: 0.0051  max mem: 4316
# Epoch: [0]  [ 720/1000]  eta: 0:02:53  lr: 0.003610  loss: 0.0644 (0.1518)  loss_classifier: 0.0210 (0.0702)  loss_box_reg: 0.0170 (0.0479)  loss_objectness: 0.0025 (0.0096)  loss_rpn_box_reg: 0.0188 (0.0241)  time: 0.6161  data: 0.0054  max mem: 4316
# Epoch: [0]  [ 730/1000]  eta: 0:02:47  lr: 0.003660  loss: 0.0795 (0.1515)  loss_classifier: 0.0327 (0.0700)  loss_box_reg: 0.0207 (0.0477)  loss_objectness: 0.0051 (0.0097)  loss_rpn_box_reg: 0.0200 (0.0240)  time: 0.6186  data: 0.0059  max mem: 4316
# Epoch: [0]  [ 740/1000]  eta: 0:02:41  lr: 0.003710  loss: 0.0971 (0.1507)  loss_classifier: 0.0341 (0.0695)  loss_box_reg: 0.0235 (0.0474)  loss_objectness: 0.0027 (0.0096)  loss_rpn_box_reg: 0.0246 (0.0241)  time: 0.6298  data: 0.0058  max mem: 4316
# Epoch: [0]  [ 750/1000]  eta: 0:02:35  lr: 0.003760  loss: 0.0775 (0.1498)  loss_classifier: 0.0299 (0.0691)  loss_box_reg: 0.0227 (0.0471)  loss_objectness: 0.0026 (0.0096)  loss_rpn_box_reg: 0.0148 (0.0241)  time: 0.6321  data: 0.0065  max mem: 4316
# Epoch: [0]  [ 760/1000]  eta: 0:02:28  lr: 0.003810  loss: 0.0707 (0.1490)  loss_classifier: 0.0295 (0.0687)  loss_box_reg: 0.0220 (0.0468)  loss_objectness: 0.0023 (0.0095)  loss_rpn_box_reg: 0.0148 (0.0241)  time: 0.5958  data: 0.0062  max mem: 4316
# Epoch: [0]  [ 770/1000]  eta: 0:02:22  lr: 0.003860  loss: 0.0741 (0.1484)  loss_classifier: 0.0282 (0.0683)  loss_box_reg: 0.0204 (0.0465)  loss_objectness: 0.0033 (0.0094)  loss_rpn_box_reg: 0.0208 (0.0242)  time: 0.5839  data: 0.0055  max mem: 4316
# Epoch: [0]  [ 780/1000]  eta: 0:02:16  lr: 0.003910  loss: 0.0953 (0.1480)  loss_classifier: 0.0317 (0.0680)  loss_box_reg: 0.0262 (0.0463)  loss_objectness: 0.0037 (0.0094)  loss_rpn_box_reg: 0.0208 (0.0243)  time: 0.6154  data: 0.0059  max mem: 4316
# Epoch: [0]  [ 790/1000]  eta: 0:02:10  lr: 0.003960  loss: 0.0953 (0.1473)  loss_classifier: 0.0332 (0.0677)  loss_box_reg: 0.0185 (0.0461)  loss_objectness: 0.0039 (0.0093)  loss_rpn_box_reg: 0.0260 (0.0242)  time: 0.6191  data: 0.0062  max mem: 4316
# Epoch: [0]  [ 800/1000]  eta: 0:02:03  lr: 0.004010  loss: 0.0768 (0.1466)  loss_classifier: 0.0309 (0.0673)  loss_box_reg: 0.0169 (0.0458)  loss_objectness: 0.0020 (0.0093)  loss_rpn_box_reg: 0.0236 (0.0242)  time: 0.6105  data: 0.0073  max mem: 4316
# Epoch: [0]  [ 810/1000]  eta: 0:01:57  lr: 0.004060  loss: 0.0730 (0.1461)  loss_classifier: 0.0297 (0.0670)  loss_box_reg: 0.0217 (0.0457)  loss_objectness: 0.0019 (0.0092)  loss_rpn_box_reg: 0.0222 (0.0242)  time: 0.6124  data: 0.0070  max mem: 4316
# Epoch: [0]  [ 820/1000]  eta: 0:01:51  lr: 0.004110  loss: 0.0900 (0.1459)  loss_classifier: 0.0378 (0.0670)  loss_box_reg: 0.0321 (0.0457)  loss_objectness: 0.0034 (0.0092)  loss_rpn_box_reg: 0.0101 (0.0240)  time: 0.6451  data: 0.0063  max mem: 4316
# Epoch: [0]  [ 830/1000]  eta: 0:01:45  lr: 0.004160  loss: 0.1016 (0.1452)  loss_classifier: 0.0455 (0.0666)  loss_box_reg: 0.0340 (0.0455)  loss_objectness: 0.0032 (0.0091)  loss_rpn_box_reg: 0.0098 (0.0240)  time: 0.6435  data: 0.0062  max mem: 4316
# Epoch: [0]  [ 840/1000]  eta: 0:01:39  lr: 0.004210  loss: 0.0870 (0.1445)  loss_classifier: 0.0308 (0.0663)  loss_box_reg: 0.0203 (0.0452)  loss_objectness: 0.0023 (0.0090)  loss_rpn_box_reg: 0.0154 (0.0239)  time: 0.5848  data: 0.0057  max mem: 4316
# Epoch: [0]  [ 850/1000]  eta: 0:01:32  lr: 0.004260  loss: 0.0750 (0.1438)  loss_classifier: 0.0287 (0.0660)  loss_box_reg: 0.0175 (0.0449)  loss_objectness: 0.0019 (0.0090)  loss_rpn_box_reg: 0.0173 (0.0240)  time: 0.5810  data: 0.0056  max mem: 4316
# Epoch: [0]  [ 860/1000]  eta: 0:01:26  lr: 0.004310  loss: 0.0753 (0.1434)  loss_classifier: 0.0290 (0.0657)  loss_box_reg: 0.0202 (0.0448)  loss_objectness: 0.0036 (0.0090)  loss_rpn_box_reg: 0.0165 (0.0239)  time: 0.6021  data: 0.0059  max mem: 4316
# Epoch: [0]  [ 870/1000]  eta: 0:01:20  lr: 0.004360  loss: 0.0747 (0.1432)  loss_classifier: 0.0286 (0.0657)  loss_box_reg: 0.0233 (0.0447)  loss_objectness: 0.0045 (0.0090)  loss_rpn_box_reg: 0.0184 (0.0239)  time: 0.5979  data: 0.0055  max mem: 4316
# Epoch: [0]  [ 880/1000]  eta: 0:01:14  lr: 0.004410  loss: 0.0799 (0.1427)  loss_classifier: 0.0286 (0.0654)  loss_box_reg: 0.0232 (0.0446)  loss_objectness: 0.0031 (0.0089)  loss_rpn_box_reg: 0.0184 (0.0238)  time: 0.6044  data: 0.0050  max mem: 4316
# Epoch: [0]  [ 890/1000]  eta: 0:01:08  lr: 0.004460  loss: 0.0953 (0.1422)  loss_classifier: 0.0392 (0.0652)  loss_box_reg: 0.0231 (0.0443)  loss_objectness: 0.0025 (0.0089)  loss_rpn_box_reg: 0.0224 (0.0239)  time: 0.6205  data: 0.0053  max mem: 4316
# Epoch: [0]  [ 900/1000]  eta: 0:01:01  lr: 0.004510  loss: 0.0953 (0.1417)  loss_classifier: 0.0393 (0.0649)  loss_box_reg: 0.0231 (0.0441)  loss_objectness: 0.0023 (0.0088)  loss_rpn_box_reg: 0.0224 (0.0239)  time: 0.6255  data: 0.0055  max mem: 4316
# Epoch: [0]  [ 910/1000]  eta: 0:00:55  lr: 0.004560  loss: 0.0991 (0.1414)  loss_classifier: 0.0440 (0.0648)  loss_box_reg: 0.0257 (0.0440)  loss_objectness: 0.0035 (0.0088)  loss_rpn_box_reg: 0.0101 (0.0238)  time: 0.6642  data: 0.0056  max mem: 4316
# Epoch: [0]  [ 920/1000]  eta: 0:00:49  lr: 0.004610  loss: 0.0771 (0.1406)  loss_classifier: 0.0307 (0.0643)  loss_box_reg: 0.0195 (0.0437)  loss_objectness: 0.0032 (0.0088)  loss_rpn_box_reg: 0.0187 (0.0238)  time: 0.6471  data: 0.0065  max mem: 4316
# Epoch: [0]  [ 930/1000]  eta: 0:00:43  lr: 0.004660  loss: 0.0771 (0.1405)  loss_classifier: 0.0280 (0.0642)  loss_box_reg: 0.0161 (0.0437)  loss_objectness: 0.0031 (0.0087)  loss_rpn_box_reg: 0.0267 (0.0239)  time: 0.6026  data: 0.0068  max mem: 4316
# Epoch: [0]  [ 940/1000]  eta: 0:00:37  lr: 0.004710  loss: 0.0980 (0.1400)  loss_classifier: 0.0372 (0.0639)  loss_box_reg: 0.0216 (0.0435)  loss_objectness: 0.0026 (0.0088)  loss_rpn_box_reg: 0.0207 (0.0238)  time: 0.6127  data: 0.0055  max mem: 4316
# Epoch: [0]  [ 950/1000]  eta: 0:00:30  lr: 0.004760  loss: 0.0796 (0.1394)  loss_classifier: 0.0291 (0.0636)  loss_box_reg: 0.0194 (0.0433)  loss_objectness: 0.0037 (0.0088)  loss_rpn_box_reg: 0.0196 (0.0237)  time: 0.6019  data: 0.0053  max mem: 4316
# Epoch: [0]  [ 960/1000]  eta: 0:00:24  lr: 0.004810  loss: 0.0829 (0.1390)  loss_classifier: 0.0418 (0.0634)  loss_box_reg: 0.0265 (0.0432)  loss_objectness: 0.0038 (0.0088)  loss_rpn_box_reg: 0.0108 (0.0236)  time: 0.6041  data: 0.0056  max mem: 4316
# Epoch: [0]  [ 970/1000]  eta: 0:00:18  lr: 0.004860  loss: 0.0938 (0.1384)  loss_classifier: 0.0382 (0.0631)  loss_box_reg: 0.0270 (0.0430)  loss_objectness: 0.0018 (0.0087)  loss_rpn_box_reg: 0.0138 (0.0236)  time: 0.6153  data: 0.0053  max mem: 4316
# Epoch: [0]  [ 980/1000]  eta: 0:00:12  lr: 0.004910  loss: 0.0830 (0.1380)  loss_classifier: 0.0302 (0.0629)  loss_box_reg: 0.0183 (0.0429)  loss_objectness: 0.0032 (0.0087)  loss_rpn_box_reg: 0.0169 (0.0236)  time: 0.5941  data: 0.0055  max mem: 4316
# Epoch: [0]  [ 990/1000]  eta: 0:00:06  lr: 0.004960  loss: 0.0854 (0.1378)  loss_classifier: 0.0409 (0.0628)  loss_box_reg: 0.0304 (0.0429)  loss_objectness: 0.0036 (0.0086)  loss_rpn_box_reg: 0.0113 (0.0235)  time: 0.5995  data: 0.0058  max mem: 4316
# Epoch: [0]  [ 999/1000]  eta: 0:00:00  lr: 0.005000  loss: 0.0817 (0.1375)  loss_classifier: 0.0371 (0.0626)  loss_box_reg: 0.0237 (0.0428)  loss_objectness: 0.0036 (0.0086)  loss_rpn_box_reg: 0.0156 (0.0235)  time: 0.6133  data: 0.0054  max mem: 4316
# Epoch: [0] Total time: 0:10:18 (0.6185 s / it)
# creating index...
# index created!
# Test:  [   0/1000]  eta: 0:15:24  model_time: 0.3113 (0.3113)  evaluator_time: 0.0062 (0.0062)  time: 0.9242  data: 0.6004  max mem: 4316
# Test:  [ 100/1000]  eta: 0:04:09  model_time: 0.2474 (0.2615)  evaluator_time: 0.0021 (0.0023)  time: 0.2740  data: 0.0052  max mem: 4316
# Test:  [ 200/1000]  eta: 0:03:54  model_time: 0.2417 (0.2632)  evaluator_time: 0.0024 (0.0026)  time: 0.2657  data: 0.0062  max mem: 4316
# Test:  [ 300/1000]  eta: 0:03:21  model_time: 0.2463 (0.2644)  evaluator_time: 0.0020 (0.0025)  time: 0.2788  data: 0.0049  max mem: 4316
# Test:  [ 400/1000]  eta: 0:02:50  model_time: 0.2445 (0.2636)  evaluator_time: 0.0020 (0.0024)  time: 0.2683  data: 0.0054  max mem: 4316
# Test:  [ 500/1000]  eta: 0:02:21  model_time: 0.2572 (0.2635)  evaluator_time: 0.0023 (0.0024)  time: 0.2724  data: 0.0059  max mem: 4316
# Test:  [ 600/1000]  eta: 0:01:54  model_time: 0.2452 (0.2638)  evaluator_time: 0.0020 (0.0024)  time: 0.2679  data: 0.0049  max mem: 4316
# Test:  [ 700/1000]  eta: 0:01:25  model_time: 0.2604 (0.2638)  evaluator_time: 0.0019 (0.0024)  time: 0.2724  data: 0.0050  max mem: 4316
# Test:  [ 800/1000]  eta: 0:00:56  model_time: 0.2424 (0.2632)  evaluator_time: 0.0020 (0.0024)  time: 0.2656  data: 0.0052  max mem: 4316
# Test:  [ 900/1000]  eta: 0:00:28  model_time: 0.2532 (0.2638)  evaluator_time: 0.0019 (0.0024)  time: 0.2798  data: 0.0063  max mem: 4316
# Test:  [ 999/1000]  eta: 0:00:00  model_time: 0.2516 (0.2632)  evaluator_time: 0.0018 (0.0024)  time: 0.2707  data: 0.0047  max mem: 4316
# Test: Total time: 0:04:41 (0.2817 s / it)
# Confusion Matrix:
#            Predicted N, Predicted P
# Actual N      --           28
# Actual P      396           737
# True positive: 737
# False positive: 28
# False negative: 396
# Precision: 96.3
# Recall: 65.0
# F1-Score: 77.7
# Global correct: 63.5
# Average row correct: ['0.0', '65.0']
# IoU: ['0.0', '63.5']
# mean IoU: 31.7
# Averaged stats: model_time: 0.2516 (0.2632)  evaluator_time: 0.0018 (0.0024)
# Accumulating evaluation results...
# DONE (t=0.23s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.447
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.659
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.535
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.605
# creating index...
# index created!
# Test:  [  0/500]  eta: 0:03:33  model_time: 0.1847 (0.1847)  evaluator_time: 0.0032 (0.0032)  time: 0.4278  data: 0.2380  max mem: 4316
# Test:  [100/500]  eta: 0:00:52  model_time: 0.1229 (0.1196)  evaluator_time: 0.0015 (0.0016)  time: 0.1294  data: 0.0035  max mem: 4316
# Test:  [200/500]  eta: 0:00:38  model_time: 0.1173 (0.1191)  evaluator_time: 0.0013 (0.0015)  time: 0.1252  data: 0.0034  max mem: 4316
# Test:  [300/500]  eta: 0:00:25  model_time: 0.1272 (0.1213)  evaluator_time: 0.0013 (0.0016)  time: 0.1356  data: 0.0030  max mem: 4316
# Test:  [400/500]  eta: 0:00:12  model_time: 0.1189 (0.1210)  evaluator_time: 0.0014 (0.0015)  time: 0.1293  data: 0.0031  max mem: 4316
# Test:  [499/500]  eta: 0:00:00  model_time: 0.1220 (0.1211)  evaluator_time: 0.0014 (0.0016)  time: 0.1277  data: 0.0030  max mem: 4316
# Test: Total time: 0:01:04 (0.1288 s / it)
# Confusion Matrix:
#            Predicted N, Predicted P
# Actual N      --           24
# Actual P      230           344
# True positive: 344
# False positive: 24
# False negative: 230
# Precision: 93.5
# Recall: 59.9
# F1-Score: 73.0
# Global correct: 57.5
# Average row correct: ['0.0', '59.9']
# IoU: ['0.0', '57.5']
# mean IoU: 28.8
# Averaged stats: model_time: 0.1220 (0.1211)  evaluator_time: 0.0014 (0.0016)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.538
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.829
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.545
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.232
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.242
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.618
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.360
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.420
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.682
# 0.5752508640289307
# 0.0
# Epoch: [1]  [   0/1000]  eta: 0:28:26  lr: 0.005000  loss: 0.1825 (0.1825)  loss_classifier: 0.1020 (0.1020)  loss_box_reg: 0.0565 (0.0565)  loss_objectness: 0.0039 (0.0039)  loss_rpn_box_reg: 0.0201 (0.0201)  time: 1.7061  data: 1.0024  max mem: 4316
# Epoch: [1]  [  10/1000]  eta: 0:12:25  lr: 0.005000  loss: 0.0810 (0.1108)  loss_classifier: 0.0345 (0.0488)  loss_box_reg: 0.0208 (0.0351)  loss_objectness: 0.0019 (0.0044)  loss_rpn_box_reg: 0.0201 (0.0225)  time: 0.7532  data: 0.0959  max mem: 4316
# Epoch: [1]  [  20/1000]  eta: 0:11:24  lr: 0.005000  loss: 0.0702 (0.0975)  loss_classifier: 0.0344 (0.0419)  loss_box_reg: 0.0191 (0.0306)  loss_objectness: 0.0019 (0.0047)  loss_rpn_box_reg: 0.0143 (0.0203)  time: 0.6478  data: 0.0055  max mem: 4316
# Epoch: [1]  [  30/1000]  eta: 0:10:50  lr: 0.005000  loss: 0.0718 (0.0934)  loss_classifier: 0.0246 (0.0394)  loss_box_reg: 0.0212 (0.0305)  loss_objectness: 0.0017 (0.0042)  loss_rpn_box_reg: 0.0138 (0.0193)  time: 0.6250  data: 0.0062  max mem: 4316
# Epoch: [1]  [  40/1000]  eta: 0:10:34  lr: 0.005000  loss: 0.0715 (0.0876)  loss_classifier: 0.0242 (0.0360)  loss_box_reg: 0.0212 (0.0281)  loss_objectness: 0.0012 (0.0036)  loss_rpn_box_reg: 0.0132 (0.0199)  time: 0.6212  data: 0.0063  max mem: 4316
# Epoch: [1]  [  50/1000]  eta: 0:10:20  lr: 0.005000  loss: 0.0682 (0.0833)  loss_classifier: 0.0224 (0.0337)  loss_box_reg: 0.0168 (0.0260)  loss_objectness: 0.0013 (0.0033)  loss_rpn_box_reg: 0.0231 (0.0203)  time: 0.6258  data: 0.0060  max mem: 4316
# Epoch: [1]  [  60/1000]  eta: 0:10:13  lr: 0.005000  loss: 0.0724 (0.0852)  loss_classifier: 0.0256 (0.0352)  loss_box_reg: 0.0155 (0.0257)  loss_objectness: 0.0016 (0.0032)  loss_rpn_box_reg: 0.0186 (0.0212)  time: 0.6356  data: 0.0057  max mem: 4316
# Epoch: [1]  [  70/1000]  eta: 0:10:06  lr: 0.005000  loss: 0.0787 (0.0831)  loss_classifier: 0.0297 (0.0343)  loss_box_reg: 0.0217 (0.0251)  loss_objectness: 0.0020 (0.0034)  loss_rpn_box_reg: 0.0137 (0.0204)  time: 0.6487  data: 0.0054  max mem: 4316
# Epoch: [1]  [  80/1000]  eta: 0:09:54  lr: 0.005000  loss: 0.0769 (0.0858)  loss_classifier: 0.0290 (0.0352)  loss_box_reg: 0.0223 (0.0259)  loss_objectness: 0.0025 (0.0040)  loss_rpn_box_reg: 0.0141 (0.0206)  time: 0.6268  data: 0.0054  max mem: 4316
# Epoch: [1]  [  90/1000]  eta: 0:09:46  lr: 0.005000  loss: 0.0788 (0.0864)  loss_classifier: 0.0310 (0.0358)  loss_box_reg: 0.0223 (0.0263)  loss_objectness: 0.0033 (0.0042)  loss_rpn_box_reg: 0.0162 (0.0201)  time: 0.6199  data: 0.0053  max mem: 4316
# Epoch: [1]  [ 100/1000]  eta: 0:09:38  lr: 0.005000  loss: 0.0699 (0.0854)  loss_classifier: 0.0278 (0.0353)  loss_box_reg: 0.0183 (0.0255)  loss_objectness: 0.0033 (0.0040)  loss_rpn_box_reg: 0.0191 (0.0204)  time: 0.6272  data: 0.0053  max mem: 4316
# Epoch: [1]  [ 110/1000]  eta: 0:09:32  lr: 0.005000  loss: 0.0743 (0.0855)  loss_classifier: 0.0288 (0.0353)  loss_box_reg: 0.0188 (0.0259)  loss_objectness: 0.0033 (0.0040)  loss_rpn_box_reg: 0.0191 (0.0202)  time: 0.6374  data: 0.0056  max mem: 4316
# Epoch: [1]  [ 120/1000]  eta: 0:09:28  lr: 0.005000  loss: 0.0958 (0.0887)  loss_classifier: 0.0311 (0.0376)  loss_box_reg: 0.0260 (0.0264)  loss_objectness: 0.0044 (0.0042)  loss_rpn_box_reg: 0.0093 (0.0204)  time: 0.6659  data: 0.0058  max mem: 4316
# Epoch: [1]  [ 130/1000]  eta: 0:09:18  lr: 0.005000  loss: 0.0749 (0.0870)  loss_classifier: 0.0343 (0.0369)  loss_box_reg: 0.0235 (0.0259)  loss_objectness: 0.0031 (0.0041)  loss_rpn_box_reg: 0.0086 (0.0201)  time: 0.6335  data: 0.0061  max mem: 4316
# Epoch: [1]  [ 140/1000]  eta: 0:09:14  lr: 0.005000  loss: 0.0749 (0.0883)  loss_classifier: 0.0343 (0.0379)  loss_box_reg: 0.0212 (0.0261)  loss_objectness: 0.0031 (0.0043)  loss_rpn_box_reg: 0.0147 (0.0200)  time: 0.6369  data: 0.0468  max mem: 4316
# Epoch: [1]  [ 150/1000]  eta: 0:09:05  lr: 0.005000  loss: 0.0810 (0.0915)  loss_classifier: 0.0336 (0.0391)  loss_box_reg: 0.0192 (0.0265)  loss_objectness: 0.0026 (0.0050)  loss_rpn_box_reg: 0.0207 (0.0209)  time: 0.6432  data: 0.0463  max mem: 4316
# Epoch: [1]  [ 160/1000]  eta: 0:08:57  lr: 0.005000  loss: 0.0966 (0.0930)  loss_classifier: 0.0369 (0.0398)  loss_box_reg: 0.0192 (0.0265)  loss_objectness: 0.0052 (0.0056)  loss_rpn_box_reg: 0.0235 (0.0211)  time: 0.6023  data: 0.0053  max mem: 4316
# Epoch: [1]  [ 170/1000]  eta: 0:08:49  lr: 0.005000  loss: 0.0988 (0.0929)  loss_classifier: 0.0401 (0.0397)  loss_box_reg: 0.0193 (0.0259)  loss_objectness: 0.0075 (0.0058)  loss_rpn_box_reg: 0.0265 (0.0214)  time: 0.6034  data: 0.0051  max mem: 4316
# Epoch: [1]  [ 180/1000]  eta: 0:08:41  lr: 0.005000  loss: 0.0866 (0.0948)  loss_classifier: 0.0371 (0.0414)  loss_box_reg: 0.0192 (0.0265)  loss_objectness: 0.0050 (0.0058)  loss_rpn_box_reg: 0.0211 (0.0211)  time: 0.6110  data: 0.0059  max mem: 4370
# Epoch: [1]  [ 190/1000]  eta: 0:08:36  lr: 0.005000  loss: 0.1004 (0.0957)  loss_classifier: 0.0494 (0.0421)  loss_box_reg: 0.0235 (0.0266)  loss_objectness: 0.0039 (0.0057)  loss_rpn_box_reg: 0.0185 (0.0212)  time: 0.6417  data: 0.0062  max mem: 4370
# Epoch: [1]  [ 200/1000]  eta: 0:08:29  lr: 0.005000  loss: 0.0944 (0.0956)  loss_classifier: 0.0392 (0.0421)  loss_box_reg: 0.0217 (0.0264)  loss_objectness: 0.0030 (0.0059)  loss_rpn_box_reg: 0.0205 (0.0212)  time: 0.6403  data: 0.0058  max mem: 4370
# Epoch: [1]  [ 210/1000]  eta: 0:08:20  lr: 0.005000  loss: 0.0861 (0.0966)  loss_classifier: 0.0336 (0.0423)  loss_box_reg: 0.0257 (0.0267)  loss_objectness: 0.0038 (0.0064)  loss_rpn_box_reg: 0.0201 (0.0212)  time: 0.5943  data: 0.0061  max mem: 4370
# Epoch: [1]  [ 220/1000]  eta: 0:08:12  lr: 0.005000  loss: 0.0817 (0.0958)  loss_classifier: 0.0357 (0.0420)  loss_box_reg: 0.0308 (0.0267)  loss_objectness: 0.0021 (0.0062)  loss_rpn_box_reg: 0.0159 (0.0209)  time: 0.5726  data: 0.0064  max mem: 4370
# Epoch: [1]  [ 230/1000]  eta: 0:08:04  lr: 0.005000  loss: 0.0672 (0.0948)  loss_classifier: 0.0305 (0.0414)  loss_box_reg: 0.0200 (0.0264)  loss_objectness: 0.0018 (0.0061)  loss_rpn_box_reg: 0.0070 (0.0210)  time: 0.5798  data: 0.0056  max mem: 4370
# Epoch: [1]  [ 240/1000]  eta: 0:07:57  lr: 0.005000  loss: 0.0801 (0.0949)  loss_classifier: 0.0346 (0.0415)  loss_box_reg: 0.0224 (0.0266)  loss_objectness: 0.0020 (0.0060)  loss_rpn_box_reg: 0.0177 (0.0208)  time: 0.5999  data: 0.0048  max mem: 4370
# Epoch: [1]  [ 250/1000]  eta: 0:07:51  lr: 0.005000  loss: 0.0856 (0.0949)  loss_classifier: 0.0346 (0.0413)  loss_box_reg: 0.0224 (0.0268)  loss_objectness: 0.0032 (0.0059)  loss_rpn_box_reg: 0.0177 (0.0209)  time: 0.6237  data: 0.0050  max mem: 4370
# Epoch: [1]  [ 260/1000]  eta: 0:07:44  lr: 0.005000  loss: 0.0819 (0.0945)  loss_classifier: 0.0305 (0.0411)  loss_box_reg: 0.0210 (0.0267)  loss_objectness: 0.0034 (0.0059)  loss_rpn_box_reg: 0.0146 (0.0208)  time: 0.6272  data: 0.0051  max mem: 4370
# Epoch: [1]  [ 270/1000]  eta: 0:07:38  lr: 0.005000  loss: 0.0753 (0.0948)  loss_classifier: 0.0311 (0.0412)  loss_box_reg: 0.0220 (0.0271)  loss_objectness: 0.0032 (0.0058)  loss_rpn_box_reg: 0.0114 (0.0207)  time: 0.6206  data: 0.0054  max mem: 4370
# Epoch: [1]  [ 280/1000]  eta: 0:07:34  lr: 0.005000  loss: 0.0794 (0.0959)  loss_classifier: 0.0390 (0.0417)  loss_box_reg: 0.0235 (0.0276)  loss_objectness: 0.0030 (0.0059)  loss_rpn_box_reg: 0.0188 (0.0208)  time: 0.6715  data: 0.0541  max mem: 4370
# Epoch: [1]  [ 290/1000]  eta: 0:07:29  lr: 0.005000  loss: 0.0877 (0.0961)  loss_classifier: 0.0300 (0.0415)  loss_box_reg: 0.0288 (0.0279)  loss_objectness: 0.0038 (0.0060)  loss_rpn_box_reg: 0.0139 (0.0208)  time: 0.7060  data: 0.0543  max mem: 4370
# Epoch: [1]  [ 300/1000]  eta: 0:07:22  lr: 0.005000  loss: 0.0769 (0.0952)  loss_classifier: 0.0300 (0.0411)  loss_box_reg: 0.0258 (0.0276)  loss_objectness: 0.0038 (0.0059)  loss_rpn_box_reg: 0.0121 (0.0205)  time: 0.6431  data: 0.0058  max mem: 4370
# Epoch: [1]  [ 310/1000]  eta: 0:07:15  lr: 0.005000  loss: 0.0696 (0.0945)  loss_classifier: 0.0310 (0.0407)  loss_box_reg: 0.0203 (0.0274)  loss_objectness: 0.0038 (0.0059)  loss_rpn_box_reg: 0.0121 (0.0205)  time: 0.6006  data: 0.0057  max mem: 4370
# Epoch: [1]  [ 320/1000]  eta: 0:07:08  lr: 0.005000  loss: 0.0608 (0.0933)  loss_classifier: 0.0178 (0.0399)  loss_box_reg: 0.0113 (0.0270)  loss_objectness: 0.0039 (0.0059)  loss_rpn_box_reg: 0.0169 (0.0206)  time: 0.6109  data: 0.0054  max mem: 4370
# Epoch: [1]  [ 330/1000]  eta: 0:07:02  lr: 0.005000  loss: 0.0618 (0.0927)  loss_classifier: 0.0169 (0.0397)  loss_box_reg: 0.0107 (0.0267)  loss_objectness: 0.0033 (0.0058)  loss_rpn_box_reg: 0.0117 (0.0205)  time: 0.6234  data: 0.0054  max mem: 4370
# Epoch: [1]  [ 340/1000]  eta: 0:06:56  lr: 0.005000  loss: 0.0671 (0.0923)  loss_classifier: 0.0234 (0.0393)  loss_box_reg: 0.0140 (0.0264)  loss_objectness: 0.0031 (0.0057)  loss_rpn_box_reg: 0.0244 (0.0209)  time: 0.6275  data: 0.0055  max mem: 4370
# Epoch: [1]  [ 350/1000]  eta: 0:06:49  lr: 0.005000  loss: 0.0728 (0.0922)  loss_classifier: 0.0237 (0.0392)  loss_box_reg: 0.0159 (0.0264)  loss_objectness: 0.0031 (0.0059)  loss_rpn_box_reg: 0.0230 (0.0208)  time: 0.6236  data: 0.0055  max mem: 4370
# Epoch: [1]  [ 360/1000]  eta: 0:06:43  lr: 0.005000  loss: 0.0672 (0.0914)  loss_classifier: 0.0214 (0.0385)  loss_box_reg: 0.0156 (0.0261)  loss_objectness: 0.0037 (0.0058)  loss_rpn_box_reg: 0.0174 (0.0210)  time: 0.6258  data: 0.0057  max mem: 4370
# Epoch: [1]  [ 370/1000]  eta: 0:06:36  lr: 0.005000  loss: 0.0675 (0.0915)  loss_classifier: 0.0206 (0.0386)  loss_box_reg: 0.0153 (0.0260)  loss_objectness: 0.0037 (0.0058)  loss_rpn_box_reg: 0.0232 (0.0211)  time: 0.6188  data: 0.0056  max mem: 4370
# Epoch: [1]  [ 380/1000]  eta: 0:06:29  lr: 0.005000  loss: 0.0775 (0.0916)  loss_classifier: 0.0327 (0.0388)  loss_box_reg: 0.0181 (0.0260)  loss_objectness: 0.0042 (0.0060)  loss_rpn_box_reg: 0.0185 (0.0209)  time: 0.5929  data: 0.0057  max mem: 4370
# Epoch: [1]  [ 390/1000]  eta: 0:06:23  lr: 0.005000  loss: 0.0761 (0.0917)  loss_classifier: 0.0342 (0.0389)  loss_box_reg: 0.0194 (0.0261)  loss_objectness: 0.0030 (0.0059)  loss_rpn_box_reg: 0.0098 (0.0208)  time: 0.6079  data: 0.0055  max mem: 4370
# Epoch: [1]  [ 400/1000]  eta: 0:06:16  lr: 0.005000  loss: 0.0751 (0.0917)  loss_classifier: 0.0297 (0.0390)  loss_box_reg: 0.0194 (0.0260)  loss_objectness: 0.0025 (0.0059)  loss_rpn_box_reg: 0.0154 (0.0207)  time: 0.6193  data: 0.0055  max mem: 4370
# Epoch: [1]  [ 410/1000]  eta: 0:06:10  lr: 0.005000  loss: 0.0709 (0.0913)  loss_classifier: 0.0281 (0.0388)  loss_box_reg: 0.0206 (0.0259)  loss_objectness: 0.0021 (0.0058)  loss_rpn_box_reg: 0.0194 (0.0208)  time: 0.6143  data: 0.0075  max mem: 4370
# Epoch: [1]  [ 420/1000]  eta: 0:06:04  lr: 0.005000  loss: 0.0709 (0.0912)  loss_classifier: 0.0281 (0.0386)  loss_box_reg: 0.0191 (0.0258)  loss_objectness: 0.0020 (0.0058)  loss_rpn_box_reg: 0.0237 (0.0210)  time: 0.6312  data: 0.0074  max mem: 4370
# Epoch: [1]  [ 430/1000]  eta: 0:05:57  lr: 0.005000  loss: 0.0636 (0.0907)  loss_classifier: 0.0222 (0.0383)  loss_box_reg: 0.0176 (0.0258)  loss_objectness: 0.0015 (0.0057)  loss_rpn_box_reg: 0.0199 (0.0209)  time: 0.6199  data: 0.0060  max mem: 4554
# Epoch: [1]  [ 440/1000]  eta: 0:05:51  lr: 0.005000  loss: 0.0636 (0.0908)  loss_classifier: 0.0251 (0.0385)  loss_box_reg: 0.0176 (0.0258)  loss_objectness: 0.0018 (0.0057)  loss_rpn_box_reg: 0.0135 (0.0209)  time: 0.5988  data: 0.0063  max mem: 4554
# Epoch: [1]  [ 450/1000]  eta: 0:05:44  lr: 0.005000  loss: 0.0742 (0.0907)  loss_classifier: 0.0368 (0.0385)  loss_box_reg: 0.0219 (0.0257)  loss_objectness: 0.0022 (0.0056)  loss_rpn_box_reg: 0.0143 (0.0209)  time: 0.6002  data: 0.0057  max mem: 4554
# Epoch: [1]  [ 460/1000]  eta: 0:05:38  lr: 0.005000  loss: 0.0645 (0.0908)  loss_classifier: 0.0287 (0.0385)  loss_box_reg: 0.0155 (0.0258)  loss_objectness: 0.0032 (0.0056)  loss_rpn_box_reg: 0.0164 (0.0209)  time: 0.6191  data: 0.0056  max mem: 4554
# Epoch: [1]  [ 470/1000]  eta: 0:05:31  lr: 0.005000  loss: 0.0740 (0.0911)  loss_classifier: 0.0251 (0.0386)  loss_box_reg: 0.0192 (0.0258)  loss_objectness: 0.0037 (0.0056)  loss_rpn_box_reg: 0.0168 (0.0211)  time: 0.6149  data: 0.0060  max mem: 4554
# Epoch: [1]  [ 480/1000]  eta: 0:05:25  lr: 0.005000  loss: 0.0923 (0.0915)  loss_classifier: 0.0415 (0.0388)  loss_box_reg: 0.0205 (0.0258)  loss_objectness: 0.0047 (0.0057)  loss_rpn_box_reg: 0.0168 (0.0212)  time: 0.6132  data: 0.0058  max mem: 4554
# Epoch: [1]  [ 490/1000]  eta: 0:05:18  lr: 0.005000  loss: 0.0850 (0.0917)  loss_classifier: 0.0301 (0.0389)  loss_box_reg: 0.0205 (0.0259)  loss_objectness: 0.0037 (0.0056)  loss_rpn_box_reg: 0.0269 (0.0213)  time: 0.6107  data: 0.0053  max mem: 4554
# Epoch: [1]  [ 500/1000]  eta: 0:05:12  lr: 0.005000  loss: 0.0746 (0.0913)  loss_classifier: 0.0294 (0.0387)  loss_box_reg: 0.0212 (0.0259)  loss_objectness: 0.0026 (0.0056)  loss_rpn_box_reg: 0.0146 (0.0211)  time: 0.6017  data: 0.0052  max mem: 4554
# Epoch: [1]  [ 510/1000]  eta: 0:05:06  lr: 0.005000  loss: 0.0746 (0.0912)  loss_classifier: 0.0294 (0.0387)  loss_box_reg: 0.0212 (0.0258)  loss_objectness: 0.0022 (0.0056)  loss_rpn_box_reg: 0.0116 (0.0211)  time: 0.6183  data: 0.0055  max mem: 4554
# Epoch: [1]  [ 520/1000]  eta: 0:04:59  lr: 0.005000  loss: 0.0675 (0.0910)  loss_classifier: 0.0346 (0.0387)  loss_box_reg: 0.0147 (0.0257)  loss_objectness: 0.0025 (0.0056)  loss_rpn_box_reg: 0.0095 (0.0209)  time: 0.6204  data: 0.0054  max mem: 4554
# Epoch: [1]  [ 530/1000]  eta: 0:04:53  lr: 0.005000  loss: 0.0810 (0.0912)  loss_classifier: 0.0384 (0.0389)  loss_box_reg: 0.0234 (0.0259)  loss_objectness: 0.0019 (0.0056)  loss_rpn_box_reg: 0.0102 (0.0208)  time: 0.6242  data: 0.0060  max mem: 4554
# Epoch: [1]  [ 540/1000]  eta: 0:04:47  lr: 0.005000  loss: 0.0839 (0.0912)  loss_classifier: 0.0375 (0.0388)  loss_box_reg: 0.0284 (0.0259)  loss_objectness: 0.0016 (0.0055)  loss_rpn_box_reg: 0.0155 (0.0209)  time: 0.6074  data: 0.0061  max mem: 4554
# Epoch: [1]  [ 550/1000]  eta: 0:04:40  lr: 0.005000  loss: 0.0666 (0.0907)  loss_classifier: 0.0192 (0.0385)  loss_box_reg: 0.0124 (0.0257)  loss_objectness: 0.0022 (0.0055)  loss_rpn_box_reg: 0.0255 (0.0210)  time: 0.5833  data: 0.0059  max mem: 4554
# Epoch: [1]  [ 560/1000]  eta: 0:04:34  lr: 0.005000  loss: 0.0602 (0.0902)  loss_classifier: 0.0192 (0.0383)  loss_box_reg: 0.0124 (0.0256)  loss_objectness: 0.0020 (0.0054)  loss_rpn_box_reg: 0.0175 (0.0210)  time: 0.6111  data: 0.0066  max mem: 4554
# Epoch: [1]  [ 570/1000]  eta: 0:04:28  lr: 0.005000  loss: 0.0658 (0.0901)  loss_classifier: 0.0260 (0.0382)  loss_box_reg: 0.0172 (0.0255)  loss_objectness: 0.0021 (0.0055)  loss_rpn_box_reg: 0.0156 (0.0209)  time: 0.6218  data: 0.0076  max mem: 4554
# Epoch: [1]  [ 580/1000]  eta: 0:04:22  lr: 0.005000  loss: 0.0662 (0.0897)  loss_classifier: 0.0231 (0.0379)  loss_box_reg: 0.0169 (0.0254)  loss_objectness: 0.0020 (0.0054)  loss_rpn_box_reg: 0.0233 (0.0210)  time: 0.6387  data: 0.0068  max mem: 4554
# Epoch: [1]  [ 590/1000]  eta: 0:04:15  lr: 0.005000  loss: 0.0638 (0.0893)  loss_classifier: 0.0237 (0.0377)  loss_box_reg: 0.0169 (0.0253)  loss_objectness: 0.0014 (0.0054)  loss_rpn_box_reg: 0.0233 (0.0210)  time: 0.6349  data: 0.0053  max mem: 4554
# Epoch: [1]  [ 600/1000]  eta: 0:04:09  lr: 0.005000  loss: 0.0623 (0.0888)  loss_classifier: 0.0238 (0.0374)  loss_box_reg: 0.0114 (0.0251)  loss_objectness: 0.0014 (0.0053)  loss_rpn_box_reg: 0.0183 (0.0209)  time: 0.6021  data: 0.0055  max mem: 4554
# Epoch: [1]  [ 610/1000]  eta: 0:04:03  lr: 0.005000  loss: 0.0716 (0.0892)  loss_classifier: 0.0243 (0.0376)  loss_box_reg: 0.0135 (0.0253)  loss_objectness: 0.0037 (0.0054)  loss_rpn_box_reg: 0.0190 (0.0210)  time: 0.6044  data: 0.0057  max mem: 4554
# Epoch: [1]  [ 620/1000]  eta: 0:03:56  lr: 0.005000  loss: 0.0795 (0.0894)  loss_classifier: 0.0211 (0.0377)  loss_box_reg: 0.0135 (0.0253)  loss_objectness: 0.0032 (0.0054)  loss_rpn_box_reg: 0.0203 (0.0210)  time: 0.6011  data: 0.0057  max mem: 4554
# Epoch: [1]  [ 630/1000]  eta: 0:03:50  lr: 0.005000  loss: 0.0665 (0.0894)  loss_classifier: 0.0195 (0.0377)  loss_box_reg: 0.0147 (0.0253)  loss_objectness: 0.0023 (0.0053)  loss_rpn_box_reg: 0.0190 (0.0210)  time: 0.5979  data: 0.0054  max mem: 4554
# Epoch: [1]  [ 640/1000]  eta: 0:03:43  lr: 0.005000  loss: 0.0769 (0.0896)  loss_classifier: 0.0278 (0.0379)  loss_box_reg: 0.0295 (0.0255)  loss_objectness: 0.0050 (0.0054)  loss_rpn_box_reg: 0.0141 (0.0209)  time: 0.6027  data: 0.0052  max mem: 4554
# Epoch: [1]  [ 650/1000]  eta: 0:03:37  lr: 0.005000  loss: 0.1038 (0.0897)  loss_classifier: 0.0389 (0.0379)  loss_box_reg: 0.0333 (0.0256)  loss_objectness: 0.0062 (0.0054)  loss_rpn_box_reg: 0.0095 (0.0207)  time: 0.6337  data: 0.0055  max mem: 4554
# Epoch: [1]  [ 660/1000]  eta: 0:03:31  lr: 0.005000  loss: 0.0906 (0.0901)  loss_classifier: 0.0496 (0.0382)  loss_box_reg: 0.0257 (0.0257)  loss_objectness: 0.0032 (0.0055)  loss_rpn_box_reg: 0.0095 (0.0207)  time: 0.6473  data: 0.0056  max mem: 4554
# Epoch: [1]  [ 670/1000]  eta: 0:03:25  lr: 0.005000  loss: 0.0845 (0.0899)  loss_classifier: 0.0458 (0.0381)  loss_box_reg: 0.0245 (0.0258)  loss_objectness: 0.0019 (0.0054)  loss_rpn_box_reg: 0.0131 (0.0206)  time: 0.6143  data: 0.0055  max mem: 4554
# ...
# Epoch: [14]  [ 690/1000]  eta: 0:03:10  lr: 0.000001  loss: 0.0337 (0.0445)  loss_classifier: 0.0114 (0.0176)  loss_box_reg: 0.0068 (0.0118)  loss_objectness: 0.0010 (0.0013)  loss_rpn_box_reg: 0.0098 (0.0138)  time: 0.6053  data: 0.0055  max mem: 4578
# Epoch: [14]  [ 700/1000]  eta: 0:03:04  lr: 0.000001  loss: 0.0319 (0.0446)  loss_classifier: 0.0119 (0.0176)  loss_box_reg: 0.0060 (0.0118)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0087 (0.0138)  time: 0.6243  data: 0.0054  max mem: 4578
# Epoch: [14]  [ 710/1000]  eta: 0:02:58  lr: 0.000001  loss: 0.0444 (0.0446)  loss_classifier: 0.0159 (0.0177)  loss_box_reg: 0.0087 (0.0118)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0095 (0.0138)  time: 0.6269  data: 0.0051  max mem: 4578
# Epoch: [14]  [ 720/1000]  eta: 0:02:52  lr: 0.000001  loss: 0.0444 (0.0446)  loss_classifier: 0.0193 (0.0177)  loss_box_reg: 0.0121 (0.0119)  loss_objectness: 0.0005 (0.0013)  loss_rpn_box_reg: 0.0052 (0.0137)  time: 0.6351  data: 0.0057  max mem: 4578
# Epoch: [14]  [ 730/1000]  eta: 0:02:46  lr: 0.000001  loss: 0.0365 (0.0446)  loss_classifier: 0.0172 (0.0177)  loss_box_reg: 0.0107 (0.0119)  loss_objectness: 0.0005 (0.0013)  loss_rpn_box_reg: 0.0072 (0.0137)  time: 0.6282  data: 0.0058  max mem: 4578
# Epoch: [14]  [ 740/1000]  eta: 0:02:39  lr: 0.000001  loss: 0.0364 (0.0446)  loss_classifier: 0.0118 (0.0176)  loss_box_reg: 0.0063 (0.0119)  loss_objectness: 0.0004 (0.0014)  loss_rpn_box_reg: 0.0097 (0.0137)  time: 0.6002  data: 0.0054  max mem: 4578
# Epoch: [14]  [ 750/1000]  eta: 0:02:33  lr: 0.000001  loss: 0.0311 (0.0445)  loss_classifier: 0.0122 (0.0176)  loss_box_reg: 0.0072 (0.0119)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0088 (0.0136)  time: 0.6202  data: 0.0068  max mem: 4578
# Epoch: [14]  [ 760/1000]  eta: 0:02:27  lr: 0.000001  loss: 0.0337 (0.0444)  loss_classifier: 0.0122 (0.0175)  loss_box_reg: 0.0089 (0.0118)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0097 (0.0136)  time: 0.6378  data: 0.0074  max mem: 4578
# Epoch: [14]  [ 770/1000]  eta: 0:02:21  lr: 0.000001  loss: 0.0325 (0.0443)  loss_classifier: 0.0120 (0.0175)  loss_box_reg: 0.0086 (0.0118)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0120 (0.0136)  time: 0.6207  data: 0.0058  max mem: 4578
# Epoch: [14]  [ 780/1000]  eta: 0:02:15  lr: 0.000001  loss: 0.0385 (0.0444)  loss_classifier: 0.0148 (0.0176)  loss_box_reg: 0.0073 (0.0119)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0063 (0.0136)  time: 0.6043  data: 0.0051  max mem: 4578
# Epoch: [14]  [ 790/1000]  eta: 0:02:09  lr: 0.000001  loss: 0.0426 (0.0443)  loss_classifier: 0.0160 (0.0176)  loss_box_reg: 0.0098 (0.0119)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0043 (0.0136)  time: 0.6256  data: 0.0053  max mem: 4578
# Epoch: [14]  [ 800/1000]  eta: 0:02:03  lr: 0.000001  loss: 0.0373 (0.0443)  loss_classifier: 0.0125 (0.0175)  loss_box_reg: 0.0058 (0.0118)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0118 (0.0136)  time: 0.6833  data: 0.0056  max mem: 4578
# Epoch: [14]  [ 810/1000]  eta: 0:01:57  lr: 0.000001  loss: 0.0361 (0.0443)  loss_classifier: 0.0124 (0.0175)  loss_box_reg: 0.0053 (0.0118)  loss_objectness: 0.0004 (0.0014)  loss_rpn_box_reg: 0.0093 (0.0137)  time: 0.6561  data: 0.0057  max mem: 4578
# Epoch: [14]  [ 820/1000]  eta: 0:01:50  lr: 0.000001  loss: 0.0324 (0.0443)  loss_classifier: 0.0124 (0.0175)  loss_box_reg: 0.0056 (0.0118)  loss_objectness: 0.0008 (0.0014)  loss_rpn_box_reg: 0.0119 (0.0137)  time: 0.6064  data: 0.0064  max mem: 4578
# Epoch: [14]  [ 830/1000]  eta: 0:01:44  lr: 0.000001  loss: 0.0346 (0.0444)  loss_classifier: 0.0130 (0.0175)  loss_box_reg: 0.0084 (0.0119)  loss_objectness: 0.0003 (0.0013)  loss_rpn_box_reg: 0.0119 (0.0137)  time: 0.6210  data: 0.0064  max mem: 4578
# Epoch: [14]  [ 840/1000]  eta: 0:01:38  lr: 0.000001  loss: 0.0377 (0.0446)  loss_classifier: 0.0138 (0.0175)  loss_box_reg: 0.0090 (0.0120)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0093 (0.0137)  time: 0.6300  data: 0.0062  max mem: 4578
# Epoch: [14]  [ 850/1000]  eta: 0:01:32  lr: 0.000001  loss: 0.0390 (0.0446)  loss_classifier: 0.0169 (0.0176)  loss_box_reg: 0.0090 (0.0120)  loss_objectness: 0.0008 (0.0013)  loss_rpn_box_reg: 0.0121 (0.0137)  time: 0.6017  data: 0.0066  max mem: 4578
# Epoch: [14]  [ 860/1000]  eta: 0:01:26  lr: 0.000001  loss: 0.0388 (0.0445)  loss_classifier: 0.0118 (0.0175)  loss_box_reg: 0.0073 (0.0119)  loss_objectness: 0.0008 (0.0014)  loss_rpn_box_reg: 0.0121 (0.0137)  time: 0.6013  data: 0.0060  max mem: 4578
# Epoch: [14]  [ 870/1000]  eta: 0:01:20  lr: 0.000001  loss: 0.0361 (0.0445)  loss_classifier: 0.0115 (0.0175)  loss_box_reg: 0.0058 (0.0119)  loss_objectness: 0.0011 (0.0014)  loss_rpn_box_reg: 0.0116 (0.0138)  time: 0.6058  data: 0.0058  max mem: 4578
# Epoch: [14]  [ 880/1000]  eta: 0:01:13  lr: 0.000001  loss: 0.0347 (0.0444)  loss_classifier: 0.0126 (0.0174)  loss_box_reg: 0.0059 (0.0119)  loss_objectness: 0.0010 (0.0014)  loss_rpn_box_reg: 0.0114 (0.0137)  time: 0.6248  data: 0.0059  max mem: 4578
# Epoch: [14]  [ 890/1000]  eta: 0:01:07  lr: 0.000001  loss: 0.0382 (0.0445)  loss_classifier: 0.0126 (0.0174)  loss_box_reg: 0.0082 (0.0119)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0114 (0.0138)  time: 0.6319  data: 0.0058  max mem: 4578
# Epoch: [14]  [ 900/1000]  eta: 0:01:01  lr: 0.000001  loss: 0.0428 (0.0445)  loss_classifier: 0.0151 (0.0174)  loss_box_reg: 0.0091 (0.0119)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0118 (0.0139)  time: 0.6160  data: 0.0057  max mem: 4578
# Epoch: [14]  [ 910/1000]  eta: 0:00:55  lr: 0.000001  loss: 0.0407 (0.0445)  loss_classifier: 0.0151 (0.0174)  loss_box_reg: 0.0088 (0.0119)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0109 (0.0138)  time: 0.5916  data: 0.0056  max mem: 4578
# Epoch: [14]  [ 920/1000]  eta: 0:00:49  lr: 0.000001  loss: 0.0356 (0.0444)  loss_classifier: 0.0126 (0.0173)  loss_box_reg: 0.0071 (0.0118)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0109 (0.0139)  time: 0.5794  data: 0.0059  max mem: 4578
# Epoch: [14]  [ 930/1000]  eta: 0:00:43  lr: 0.000001  loss: 0.0356 (0.0444)  loss_classifier: 0.0126 (0.0174)  loss_box_reg: 0.0062 (0.0118)  loss_objectness: 0.0005 (0.0013)  loss_rpn_box_reg: 0.0107 (0.0138)  time: 0.5881  data: 0.0060  max mem: 4578
# Epoch: [14]  [ 940/1000]  eta: 0:00:36  lr: 0.000001  loss: 0.0413 (0.0444)  loss_classifier: 0.0188 (0.0174)  loss_box_reg: 0.0077 (0.0118)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0089 (0.0138)  time: 0.6143  data: 0.0057  max mem: 4578
# Epoch: [14]  [ 950/1000]  eta: 0:00:30  lr: 0.000001  loss: 0.0363 (0.0443)  loss_classifier: 0.0166 (0.0174)  loss_box_reg: 0.0071 (0.0118)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0089 (0.0138)  time: 0.6048  data: 0.0056  max mem: 4578
# Epoch: [14]  [ 960/1000]  eta: 0:00:24  lr: 0.000001  loss: 0.0427 (0.0444)  loss_classifier: 0.0183 (0.0175)  loss_box_reg: 0.0090 (0.0118)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0091 (0.0138)  time: 0.5912  data: 0.0058  max mem: 4578
# Epoch: [14]  [ 970/1000]  eta: 0:00:18  lr: 0.000001  loss: 0.0469 (0.0445)  loss_classifier: 0.0221 (0.0175)  loss_box_reg: 0.0119 (0.0118)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0104 (0.0138)  time: 0.6149  data: 0.0059  max mem: 4578
# Epoch: [14]  [ 980/1000]  eta: 0:00:12  lr: 0.000001  loss: 0.0411 (0.0447)  loss_classifier: 0.0201 (0.0175)  loss_box_reg: 0.0084 (0.0119)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0154 (0.0139)  time: 0.5955  data: 0.0060  max mem: 4578
# Epoch: [14]  [ 990/1000]  eta: 0:00:06  lr: 0.000001  loss: 0.0389 (0.0448)  loss_classifier: 0.0184 (0.0176)  loss_box_reg: 0.0084 (0.0120)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0119 (0.0138)  time: 0.5954  data: 0.0060  max mem: 4578
# Epoch: [14]  [ 999/1000]  eta: 0:00:00  lr: 0.000001  loss: 0.0353 (0.0448)  loss_classifier: 0.0142 (0.0176)  loss_box_reg: 0.0080 (0.0120)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0065 (0.0138)  time: 0.6411  data: 0.0058  max mem: 4578
# Epoch: [14] Total time: 0:10:15 (0.6157 s / it)
# creating index...
# index created!
# Test:  [   0/1000]  eta: 0:14:48  model_time: 0.3155 (0.3155)  evaluator_time: 0.0045 (0.0045)  time: 0.8886  data: 0.5552  max mem: 4578
# Test:  [ 100/1000]  eta: 0:04:11  model_time: 0.2497 (0.2618)  evaluator_time: 0.0020 (0.0025)  time: 0.2754  data: 0.0058  max mem: 4578
# Test:  [ 200/1000]  eta: 0:03:45  model_time: 0.2509 (0.2661)  evaluator_time: 0.0023 (0.0025)  time: 0.2923  data: 0.0083  max mem: 4578
# Test:  [ 300/1000]  eta: 0:03:18  model_time: 0.2414 (0.2653)  evaluator_time: 0.0020 (0.0025)  time: 0.2762  data: 0.0061  max mem: 4578
# Test:  [ 400/1000]  eta: 0:02:48  model_time: 0.2539 (0.2640)  evaluator_time: 0.0021 (0.0024)  time: 0.2742  data: 0.0056  max mem: 4578
# Test:  [ 500/1000]  eta: 0:02:19  model_time: 0.2482 (0.2636)  evaluator_time: 0.0020 (0.0024)  time: 0.2794  data: 0.0055  max mem: 4578
# Test:  [ 600/1000]  eta: 0:01:51  model_time: 0.2627 (0.2630)  evaluator_time: 0.0021 (0.0024)  time: 0.2806  data: 0.0059  max mem: 4578
# Test:  [ 700/1000]  eta: 0:01:24  model_time: 0.2483 (0.2642)  evaluator_time: 0.0029 (0.0024)  time: 0.2964  data: 0.0204  max mem: 4578
# Test:  [ 800/1000]  eta: 0:00:56  model_time: 0.2416 (0.2631)  evaluator_time: 0.0020 (0.0024)  time: 0.2716  data: 0.0062  max mem: 4578
# Test:  [ 900/1000]  eta: 0:00:28  model_time: 0.2593 (0.2631)  evaluator_time: 0.0028 (0.0024)  time: 0.2819  data: 0.0096  max mem: 4578
# Test:  [ 999/1000]  eta: 0:00:00  model_time: 0.2432 (0.2630)  evaluator_time: 0.0020 (0.0024)  time: 0.2831  data: 0.0062  max mem: 4578
# Test: Total time: 0:04:40 (0.2804 s / it)
# Confusion Matrix:
#            Predicted N, Predicted P
# Actual N      --           30
# Actual P      26           1143
# True positive: 1143
# False positive: 30
# False negative: 26
# Precision: 97.4
# Recall: 97.8
# F1-Score: 97.6
# Global correct: 95.3
# Average row correct: ['0.0', '97.8']
# IoU: ['0.0', '95.3']
# mean IoU: 47.7
# Averaged stats: model_time: 0.2432 (0.2630)  evaluator_time: 0.0020 (0.0024)
# Accumulating evaluation results...
# DONE (t=0.19s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.535
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.597
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.191
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.232
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.542
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.610
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.307
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
# creating index...
# index created!
# Test:  [  0/500]  eta: 0:04:00  model_time: 0.1890 (0.1890)  evaluator_time: 0.0039 (0.0039)  time: 0.4819  data: 0.2867  max mem: 4578
# Test:  [100/500]  eta: 0:00:52  model_time: 0.1213 (0.1202)  evaluator_time: 0.0017 (0.0019)  time: 0.1311  data: 0.0040  max mem: 4578
# Test:  [200/500]  eta: 0:00:38  model_time: 0.1167 (0.1190)  evaluator_time: 0.0016 (0.0018)  time: 0.1258  data: 0.0037  max mem: 4578
# Test:  [300/500]  eta: 0:00:25  model_time: 0.1279 (0.1209)  evaluator_time: 0.0017 (0.0018)  time: 0.1366  data: 0.0034  max mem: 4578
# Test:  [400/500]  eta: 0:00:12  model_time: 0.1206 (0.1208)  evaluator_time: 0.0017 (0.0018)  time: 0.1297  data: 0.0035  max mem: 4578
# Test:  [499/500]  eta: 0:00:00  model_time: 0.1161 (0.1208)  evaluator_time: 0.0014 (0.0018)  time: 0.1249  data: 0.0030  max mem: 4578
# Test: Total time: 0:01:04 (0.1294 s / it)
# Confusion Matrix:
#            Predicted N, Predicted P
# Actual N      --           29
# Actual P      84           489
# True positive: 489
# False positive: 29
# False negative: 84
# Precision: 94.4
# Recall: 85.3
# F1-Score: 89.6
# Global correct: 81.2
# Average row correct: ['0.0', '85.3']
# IoU: ['0.0', '81.2']
# mean IoU: 40.6
# Averaged stats: model_time: 0.1161 (0.1208)  evaluator_time: 0.0014 (0.0018)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.928
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.698
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.602
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.698
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.701
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.757
# 0.8122923374176025
# 0.8230383992195129
# creating index...
# index created!
# Test:  [  0/500]  eta: 0:03:24  model_time: 0.1811 (0.1811)  evaluator_time: 0.0030 (0.0030)  time: 0.4095  data: 0.2241  max mem: 4578
# Test:  [100/500]  eta: 0:00:53  model_time: 0.1149 (0.1179)  evaluator_time: 0.0013 (0.0017)  time: 0.1253  data: 0.0030  max mem: 4578
# Test:  [200/500]  eta: 0:00:39  model_time: 0.1214 (0.1204)  evaluator_time: 0.0015 (0.0017)  time: 0.1329  data: 0.0028  max mem: 4578
# Test:  [300/500]  eta: 0:00:26  model_time: 0.1187 (0.1208)  evaluator_time: 0.0015 (0.0017)  time: 0.1265  data: 0.0032  max mem: 4578
# Test:  [400/500]  eta: 0:00:12  model_time: 0.1155 (0.1207)  evaluator_time: 0.0015 (0.0017)  time: 0.1285  data: 0.0031  max mem: 4578
# Test:  [499/500]  eta: 0:00:00  model_time: 0.1175 (0.1208)  evaluator_time: 0.0016 (0.0017)  time: 0.1258  data: 0.0033  max mem: 4578
# Test: Total time: 0:01:04 (0.1298 s / it)
# Confusion Matrix:
#            Predicted N, Predicted P
# Actual N      --           30
# Actual P      98           474
# True positive: 474
# False positive: 30
# False negative: 98
# Precision: 94.0
# Recall: 82.9
# F1-Score: 88.1
# Global correct: 78.7
# Average row correct: ['0.0', '82.9']
# IoU: ['0.0', '78.7']
# mean IoU: 39.4
# Averaged stats: model_time: 0.1175 (0.1208)  evaluator_time: 0.0016 (0.0017)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.654
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.709
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.436
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.726
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.423
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.773

# %% [markdown]
# ### Testing the model
#
# And let's now pick one image and visualize the top predicted boxes (confidence score grater than a threshold).

# %%
import cv2
from google.colab.patches import cv2_imshow

WEAPON_CATEGORY_NAMES = ['__background__', 'gun']

# pick one image
#img = Image.open('ML-Project/images/11.jpg').convert("RGB")
img = Image.open('12.jpg').convert("RGB")
transform = get_transform(train=False)
img, _ = transform(img, _)

# put the model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

#img = cv2.imread('ML-Project/images/11.jpg') # Read image with cv2
img = cv2.imread('12.jpg') # Read image with cv2

for i in range(len(prediction[0]['boxes'])):
    score = round(prediction[0]['scores'][i].item(), 2)

    if score > 0.7:
        label = WEAPON_CATEGORY_NAMES[int(prediction[0]['labels'][i].item())]
        box = prediction[0]['boxes'][i]
        txt = '{} {}'.format(label, score)
        cv2.rectangle(img, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), color=(0, 0, 255), thickness=2)
        cv2.putText(img, txt, (int(box[0]), int(box[1])-5),  cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255),thickness=1)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1140x690 at 0x7FD4917893C8>

# %% [markdown]
# ### Testing the model on video
#
# And let's now pick one video and visualize the top predicted boxes (confidence score grater than a threshold).

# %%
import cv2
from google.colab.patches import cv2_imshow
from IPython.display import clear_output
from matplotlib.pyplot import figure
from matplotlib.pyplot import title
from matplotlib.pyplot import imshow
from matplotlib.pyplot import show

WEAPON_CATEGORY_NAMES = ['__background__', 'gun']

videopath = '6.mp4'

vid = cv2.VideoCapture(videopath)

transform = get_transform(train=False)
model.eval()


for ii in range(4000):
    ret, frame = vid.read()
    pilimg = Image.fromarray(frame)
    img, _ = transform(pilimg, _)

    with torch.no_grad():
      prediction = model([img.to(device)])

    for i in range(len(prediction[0]['boxes'])):
        score = round(prediction[0]['scores'][i].item(), 2)

        if score > 0.8:
            label = WEAPON_CATEGORY_NAMES[int(prediction[0]['labels'][i].item())]
            box = prediction[0]['boxes'][i]
            txt = '{} {}'.format(label, score)
            img = cv2.rectangle(frame, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), color=(0, 255, 0), thickness=2)
            cv2.putText(frame, txt, (int(box[0]), int(box[1])-5),  cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,220,0),thickness=1)

    fig=figure(figsize=(12, 8))
    title("Video Stream")
    imshow(frame)
    show()
    clear_output(wait=True)

# %% [markdown]
# ### Testing the model on video
#
# **WARNING: this works only locally!!**

# %%
import cv2

WEAPON_CATEGORY_NAMES = ['__background__', 'gun']

videopath = '6.mp4'

vid = cv2.VideoCapture(videopath)

transform = get_transform(train=False)
model.eval()

while(True):
#for ii in range(4000):
    try:
        ret, frame = vid.read()
        pilimg = Image.fromarray(frame)
        img, _ = transform(pilimg, None)

        with torch.no_grad():
          prediction = model([img.to(device)])

        for i in range(len(prediction[0]['boxes'])):
            score = round(prediction[0]['scores'][i].item(), 2)

            if score > 0.8:
                label = WEAPON_CATEGORY_NAMES[int(prediction[0]['labels'][i].item())]
                box = prediction[0]['boxes'][i]
                txt = '{} {}'.format(label, score)
                cv2.rectangle(frame, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), color=(0, 255, 0), thickness=2)
                cv2.putText(frame, txt, (int(box[0]), int(box[1])-5),  cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,220,0),thickness=1)

        cv2.imshow('Weapons Detection',frame)
        
        if cv2.waitKey(30) & 0xFF == ord('q'):
            break
    
    except Exception:
        break

vid.release()
cv2.destroyAllWindows()
